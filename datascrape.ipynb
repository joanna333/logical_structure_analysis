# %%
import requests
import textstat # To compute readability scores (Flesch-Kincaid Grade Level)

# %%
def fetch_category_articles(category, limit=500):
    """
    Fetch articles from a specific Wikipedia category using the API.
    """
    url = f"https://en.wikipedia.org/w/api.php?action=query&list=categorymembers&cmtitle=Category:{category}&cmlimit={limit}&format=json"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        # Extract page IDs and titles
        pages = data['query']['categorymembers']
        # Collect the page details in a list
        page_info = []
        for page in pages:
            page_info.append(f"Page ID: {page['pageid']}, Title: {page['title']}")
        return page_info  # Return the list of page details
    else:
        print(f"Failed to fetch pages for category {category}: {response.status_code}")
        return []
def fetch_page_content(pageid):
    """
    Fetch content of a Wikipedia page using the pageid.
    """
    url = f"https://en.wikipedia.org/w/api.php?action=query&pageids={pageid}&prop=extracts&explaintext&format=json"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        page = data['query']['pages'][str(pageid)]
        return page.get('extract', "No content available")
    else:
        return f"Failed to fetch content: {response.status_code}"
# Categories to fetch
categories = ["Medicine", "Medical_specialties", "Health_sciences", "Human_anatomy", "Natural_sciences", "Social_sciences", "Psychology"]
# Loop through each category and fetch article details
for category in categories:
    print(f"\nFetching articles for category: {category}")
    articles = fetch_category_articles(category)
    if articles:  # Only proceed if articles were fetched successfully
        for article in articles:
            print(article)
    else:
        print(f"No articles found for category: {category}")
# Out:
# Fetching articles for category: Medicine
# Page ID: 18957, Title: Medicine
# Page ID: 14471564, Title: Outline of medicine
# Page ID: 60606212, Title: Terminology of alternative medicine
# Page ID: 23607241, Title: Anti-aging medicine
# Page ID: 75840465, Title: Anti-asthmatic agent
# Page ID: 73402513, Title: Breastmilk medicine
# Page ID: 78136945, Title: Cancer exodus hypothesis
# Page ID: 37019670, Title: Clinical handover
# Page ID: 76454282, Title: Confocal endoscopy
# Page ID: 75164769, Title: Diabetes self-management
# Page ID: 76439689, Title: Dorsal pancreatic agenesis
# Page ID: 78013627, Title: Drone-Enhanced Emergency Medical Services
# Page ID: 1966031, Title: Isotropic bands
# Page ID: 77353600, Title: LAMA2 related congenital muscular dystrophy
# Page ID: 288156, Title: List of forms of alternative medicine
# Page ID: 77815981, Title: LY-2365109
# Page ID: 1173670, Title: Pediatric endocrinology
# Page ID: 78237247, Title: Poison exon
# Page ID: 77333746, Title: RNU4-2 syndrome
# Page ID: 76556199, Title: Urinary anti-infective agent
# Page ID: 1578539, Title: Portal:Medicine
# Page ID: 69481417, Title: Category:Medicine by city
# Page ID: 63239296, Title: Category:Medicine by country
# Page ID: 69481178, Title: Category:Medicine by country subdivision
# Page ID: 69479864, Title: Category:Medicine by dependent territory
# Page ID: 64048557, Title: Category:Medicine by century
# Page ID: 64048564, Title: Category:Medicine by decade
# Page ID: 61732199, Title: Category:Medicine by year
# Page ID: 699239, Title: Category:Alternative medicine
# Page ID: 40540908, Title: Category:Clinical medicine
# Page ID: 977183, Title: Category:Veterinary medicine
# Page ID: 2233830, Title: Category:Medical lists
# Page ID: 50429085, Title: Category:Works about medicine
# Page ID: 20577125, Title: Category:Medical activism
# Page ID: 1376841, Title: Category:Medical associations
# Page ID: 12342694, Title: Category:Medicine awards
# Page ID: 31580983, Title: Category:Cause (medicine)
# Page ID: 52039034, Title: Category:Chemicals in medicine
# Page ID: 63189157, Title: Category:Health-related conspiracy theories
# Page ID: 46310619, Title: Category:Medical aspects of death
# Page ID: 65840840, Title: Category:Medical diplomacy
# Page ID: 1427229, Title: Category:Medical education
# Page ID: 709678, Title: Category:History of medicine
# Page ID: 43085224, Title: Category:Medical humanities
# Page ID: 41740698, Title: Category:Intersex and medicine
# Page ID: 14658985, Title: Category:Medical and health organizations
# Page ID: 44410156, Title: Category:Medical phenomena
# Page ID: 40554931, Title: Category:Practice of medicine
# Page ID: 75520527, Title: Category:Prescription of drugs
# Page ID: 61480828, Title: Category:Medical prevention
# Page ID: 40434952, Title: Category:Religion and medicine
# Page ID: 1169815, Title: Category:Medical research
# Page ID: 16705284, Title: Category:Medicine in society
# Page ID: 51153441, Title: Category:Medical symbols
# Page ID: 18960497, Title: Category:Medical technology
# Page ID: 38173171, Title: Category:Medical terminology
# Page ID: 40316372, Title: Category:Theory of medicine
# Page ID: 69062190, Title: Category:Medical volunteerism
# Page ID: 44848127, Title: Category:Women in medicine
# Page ID: 1258736, Title: Category:Medicine stubs
#
# Fetching articles for category: Medical_specialties
# Page ID: 3172179, Title: Medical specialty
# Page ID: 4563075, Title: Allergist
# Page ID: 8020725, Title: Arthrology
# Page ID: 73732893, Title: Civil surgeon
# Page ID: 40351046, Title: Clinical physiology
# Page ID: 44327960, Title: Conflict and Catastrophe Medicine
# Page ID: 58547945, Title: Diving Medical Examiner
# Page ID: 58547989, Title: Diving Medical Practitioner
# Page ID: 1256713, Title: Diving medicine
# Page ID: 2521593, Title: Environmental medicine
# Page ID: 70451707, Title: Exercise medicine
# Page ID: 35489063, Title: Mass gathering medicine
# Page ID: 9332763, Title: Medical entomology
# Page ID: 13013867, Title: List of medical specialty colleges in the United States
# Page ID: 11082896, Title: Medical statistics
# Page ID: 28336484, Title: Neurosurgical anesthesia
# Page ID: 8417064, Title: Occupational medicine
# Page ID: 21438807, Title: Oncology
# Page ID: 1137766, Title: Oral and maxillofacial surgery
# Page ID: 22573, Title: Otorhinolaryngology
# Page ID: 383854, Title: Parasitology
# Page ID: 24256, Title: Phoniatrics
# Page ID: 42048, Title: Plastic surgery
# Page ID: 52671, Title: Psychosomatic medicine
# Page ID: 23667782, Title: Railway surgery
# Page ID: 8954400, Title: Rural health
# Page ID: 11186659, Title: Subspecialty
# Page ID: 1072572, Title: Travel medicine
# Page ID: 75432886, Title: Triological Society
# Page ID: 7443253, Title: Venereology
# Page ID: 74641341, Title: Category:Branches of medical specialties
# Page ID: 5978828, Title: Category:Medical doctors by specialty
# Page ID: 2711518, Title: Category:Nursing specialties
# Page ID: 59398930, Title: Category:History of medical and surgical specialties
# Page ID: 53731814, Title: Category:Interdisciplinary subfields of medicine
# Page ID: 72715875, Title: Category:Medical and health organizations by subject
# Page ID: 75815688, Title: Category:Medical education by branch
# Page ID: 37582998, Title: Category:Medical literature by subject
# Page ID: 55785984, Title: Category:Addiction medicine
# Page ID: 692358, Title: Category:Andrology
# Page ID: 58835101, Title: Category:Anesthesiology
# Page ID: 1482803, Title: Category:Angiology
# Page ID: 32614364, Title: Category:Arthrology
# Page ID: 8890978, Title: Category:Audiology
# Page ID: 998164, Title: Category:Aviation medicine
# Page ID: 23589701, Title: Category:Biomedicine
# Page ID: 692364, Title: Category:Cardiology
# Page ID: 1001629, Title: Category:Dentistry
# Page ID: 722618, Title: Category:Dermatology
# Page ID: 846798, Title: Category:Emergency medicine
# Page ID: 694995, Title: Category:Endocrinology
# Page ID: 701879, Title: Category:Gastroenterology
# Page ID: 839794, Title: Category:General practice
# Page ID: 6095701, Title: Category:Medical genetics
# Page ID: 1585258, Title: Category:Geriatrics
# Page ID: 32873663, Title: Category:Gynaecology
# Page ID: 693583, Title: Category:Hematology
# Page ID: 4948614, Title: Category:Hepatology
# Page ID: 55787856, Title: Category:Hospital medicine
# Page ID: 804899, Title: Category:Immunology
# Page ID: 714493, Title: Category:Intensive care medicine
# Page ID: 31977891, Title: Category:Internal medicine
# Page ID: 19645725, Title: Category:Men's health
# Page ID: 77501966, Title: Category:Medical microbiology
# Page ID: 1046649, Title: Category:Military medicine
# Page ID: 694340, Title: Category:Nephrology
# Page ID: 714324, Title: Category:Neurology
# Page ID: 3135245, Title: Category:Nuclear medicine
# Page ID: 751173, Title: Category:Obstetrics
# Page ID: 75894179, Title: Category:Occupational medicine
# Page ID: 695159, Title: Category:Oncology
# Page ID: 765995, Title: Category:Ophthalmology
# Page ID: 27149497, Title: Category:Orthopedics
# Page ID: 44532271, Title: Category:Otorhinolaryngology
# Page ID: 1106661, Title: Category:Parasitology
# Page ID: 1311481, Title: Category:Pathology
# Page ID: 790701, Title: Category:Pediatrics
# Page ID: 30491616, Title: Category:Clinical pharmacology
# Page ID: 1305362, Title: Category:Podiatry
# Page ID: 30133979, Title: Category:Preventive medicine
# Page ID: 55667778, Title: Category:Prison healthcare
# Page ID: 718542, Title: Category:Psychiatry
# Page ID: 1311467, Title: Category:Public health
# Page ID: 709315, Title: Category:Pulmonology
# Page ID: 695053, Title: Category:Radiology
# Page ID: 57451484, Title: Category:Railway surgery
# Page ID: 1035494, Title: Category:Rehabilitation medicine
# Page ID: 714252, Title: Category:Rheumatology
# Page ID: 1490452, Title: Category:Sexual health
# Page ID: 22818569, Title: Category:Sleep medicine
# Page ID: 35602373, Title: Category:Space medicine
# Page ID: 3919497, Title: Category:Sports medicine
# Page ID: 20745673, Title: Category:Medical statistics
# Page ID: 61195031, Title: Category:Stomatologists
# Page ID: 804789, Title: Category:Surgery
# Page ID: 72115008, Title: Category:Thermal medicine
# Page ID: 1043816, Title: Category:Toxicology
# Page ID: 1282332, Title: Category:Transplantation medicine
# Page ID: 37809172, Title: Category:Tropical medicine
# Page ID: 722711, Title: Category:Urology
# Page ID: 18803907, Title: Category:Women's health
#
# Fetching articles for category: Health_sciences
# Page ID: 14002, Title: Outline of health sciences
# Page ID: 55092696, Title: Anthropomaximology
# Page ID: 31950201, Title: Biomedical sciences
# Page ID: 66997, Title: Epidemiology
# Page ID: 2118246, Title: Global health
# Page ID: 261925, Title: Health care
# Page ID: 32890301, Title: Health crisis
# Page ID: 1810614, Title: Health equity
# Page ID: 8695082, Title: Health policy
# Page ID: 14499993, Title: Health Sciences Descriptors
# Page ID: 60976, Title: Health system
# Page ID: 2379996, Title: Population health
# Page ID: 77380994, Title: Positive health
# Page ID: 463734, Title: Public health
# Page ID: 325717, Title: Publicly funded health care
# Page ID: 3085490, Title: Right to health
# Page ID: 570661, Title: Universal health care
# Page ID: 76006902, Title: Category:Health sciences by country
# Page ID: 692348, Title: Category:Medicine
# Page ID: 21120193, Title: Category:Academic health science centres
# Page ID: 8890978, Title: Category:Audiology
# Page ID: 39487561, Title: Category:Auxology
# Page ID: 37000052, Title: Category:Biological engineering
# Page ID: 888826, Title: Category:Biotechnology
# Page ID: 1001629, Title: Category:Dentistry
# Page ID: 903647, Title: Category:Epidemiology
# Page ID: 43567436, Title: Category:Health physicists
# Page ID: 64355729, Title: Category:ILAE Wikipedia Project
# Page ID: 1169815, Title: Category:Medical research
# Page ID: 2412768, Title: Category:Midwifery
# Page ID: 744245, Title: Category:Nursing
# Page ID: 75815338, Title: Category:Health sciences organizations
# Page ID: 11913576, Title: Category:Pharmaceutical sciences
# Page ID: 1004425, Title: Category:Pharmacy
# Page ID: 75815301, Title: Category:Health sciences publications
# Page ID: 1311467, Title: Category:Public health
# Page ID: 63436808, Title: Category:Health sciences schools
# Page ID: 13971852, Title: Category:Seventh-day Adventists in health science
# Page ID: 5783724, Title: Category:Social work
# Page ID: 37059210, Title: Category:Translational medicine
# Page ID: 977183, Title: Category:Veterinary medicine
#
# Fetching articles for category: Human_anatomy
# Page ID: 54176, Title: Human body
# Page ID: 58609793, Title: List of anatomy mnemonics
# Page ID: 41580850, Title: Outline of the human nervous system
# Page ID: 3191861, Title: Abdomen
# Page ID: 380167, Title: Achilles tendon
# Page ID: 8932065, Title: Adductor hiatus
# Page ID: 1946905, Title: Alveolus
# Page ID: 187700, Title: Amniotic sac
# Page ID: 41101954, Title: Anatomical terminology
# Page ID: 41491809, Title: Anatomical terms of bone
# Page ID: 41491826, Title: Anatomical terms of muscle
# Page ID: 36771910, Title: Anatomical terms of neuroanatomy
# Page ID: 20936837, Title: Anatomy Charts of the Arabs
# Page ID: 42753191, Title: Anatomy of human
# Page ID: 52495867, Title: Anorectal canal
# Page ID: 330879, Title: Anthropometry
# Page ID: 54976608, Title: Aortopulmonary space
# Page ID: 24928375, Title: Ape hand deformity
# Page ID: 5286407, Title: Apollo's belt
# Page ID: 583238, Title: Axial skeleton
# Page ID: 49216553, Title: Beclard Triangle
# Page ID: 642608, Title: The body in traditional Chinese medicine
# Page ID: 151107, Title: Body Worlds
# Page ID: 36558703, Title: Brain connectivity estimators
# Page ID: 4041623, Title: Bregma
# Page ID: 20419472, Title: Cavoatrial junction
# Page ID: 20867880, Title: Center for Anatomy of the Charité
# Page ID: 14458107, Title: Cervical artery dissection
# Page ID: 4728560, Title: Cervical rib
# Page ID: 8235976, Title: Coccygeal glomus
# Page ID: 23826998, Title: Compensatory growth (organ)
# Page ID: 13248239, Title: Composition of the human body
# Page ID: 14540546, Title: Corona of glans penis
# Page ID: 2014829, Title: Darwin's tubercle
# Page ID: 9099027, Title: Dental anatomy
# Page ID: 29361945, Title: Dermatocranium
# Page ID: 77433669, Title: Desjardins' point
# Page ID: 39369195, Title: Dorsal body cavity
# Page ID: 134880, Title: Eardrum
# Page ID: 18722719, Title: Endocranium
# Page ID: 72381654, Title: Episternal ossicles
# Page ID: 20275096, Title: Estrogenic fat
# Page ID: 233586, Title: Eustachian tube
# Page ID: 12281622, Title: Evelyn tables
# Page ID: 6669577, Title: Extensor retinaculum of the hand
# Page ID: 784628, Title: Eyelid
# Page ID: 77561753, Title: Fascial Net Plastination Project
# Page ID: 39039427, Title: Fascial spaces of the head and neck
# Page ID: 84777, Title: Fingerprint
# Page ID: 197438, Title: Fontanelle
# Page ID: 4953446, Title: Foramen singulare
# Page ID: 29289333, Title: Foreskin
# Page ID: 72364638, Title: Fossa navicularis magna
# Page ID: 2026684, Title: Glabella
# Page ID: 1784650, Title: Groin
# Page ID: 39546302, Title: Growing teeth
# Page ID: 67909501, Title: Heterocrine gland
# Page ID: 14322655, Title: Outline of human anatomy
# Page ID: 3524381, Title: Human back
# Page ID: 33470571, Title: Human fat
# Page ID: 35869003, Title: Human mouth
# Page ID: 9387918, Title: Human nose
# Page ID: 12137890, Title: Human penis
# Page ID: 1906103, Title: Human reproductive system
# Page ID: 168848, Title: Human skeleton
# Page ID: 68756, Title: Human tooth
# Page ID: 12082283, Title: Human vestigiality
# Page ID: 5000184, Title: Iliac crest
# Page ID: 51002855, Title: Inferior frontal junction
# Page ID: 75706339, Title: Institute of Human Anatomy
# Page ID: 10045930, Title: Interdental plate
# Page ID: 54842715, Title: Interoception
# Page ID: 23921047, Title: Intrascleral plexus
# Page ID: 3646263, Title: Kiesselbach's plexus
# Page ID: 15605448, Title: Kinanthropometry
# Page ID: 47069417, Title: Koch's triangle
# Page ID: 3482916, Title: Lap
# Page ID: 8727303, Title: Lateral palpebral raphe
# Page ID: 2136925, Title: Lip
# Page ID: 950991, Title: Little finger
# Page ID: 73252323, Title: Marginal sinus
# Page ID: 17716027, Title: Marionette lines
# Page ID: 1188611, Title: Mentum
# Page ID: 55972, Title: Middle ear
# Page ID: 28066528, Title: Neanderthal anatomy
# Page ID: 15647771, Title: Neurocranium
# Page ID: 51304858, Title: Neuroepigenetics
# Page ID: 3996523, Title: Palmar aponeurosis
# Page ID: 1522174, Title: Pectoral muscles
# Page ID: 32424744, Title: Pelvic tilt
# Page ID: 5395536, Title: Petrous portion
# Page ID: 24199131, Title: Ptosis (chin)
# Page ID: 43328221, Title: Radiographic anatomy
# Page ID: 27343650, Title: Rhombus of Michaelis
# Page ID: 2949602, Title: Scalene muscles
# Page ID: 11995021, Title: Skin fold
# Page ID: 15648747, Title: Splanchnocranium
# Page ID: 61886451, Title: Stafne bone cavity
# Page ID: 72363322, Title: Sternal foramen
# Page ID: 11586027, Title: Superficial cervical fascia
# Page ID: 2829577, Title: Superior thoracic aperture
# Page ID: 59392, Title: Surface anatomy
# Page ID: 30670250, Title: Table of epithelia of human organs
# Page ID: 3539392, Title: Terminologia Anatomica
# Page ID: 3329389, Title: Terry Collection
# Page ID: 33125046, Title: Trochanter
# Page ID: 843865, Title: Tubercle
# Page ID: 4545815, Title: Vena comitans
# Page ID: 7964475, Title: Vesicouterine pouch
# Page ID: 24858803, Title: Viscerocranium
# Page ID: 70238111, Title: Visible Embryo Project
# Page ID: 336950, Title: Visible Human Project
# Page ID: 77036313, Title: Wenis
# Page ID: 19400713, Title: Category:Human anatomy by organ
# Page ID: 75174157, Title: Category:Human anatomy by system
# Page ID: 3531584, Title: Category:Anthropometry
# Page ID: 44664382, Title: Category:Lists of human anatomical features
# Page ID: 57134570, Title: Category:Absent body parts
# Page ID: 77630935, Title: Category:Amniotic sac
# Page ID: 36059608, Title: Category:Anatomical variations
# Page ID: 71241032, Title: Category:Anatomy named for one who described it
# Page ID: 2355074, Title: Category:Back anatomy
# Page ID: 26723337, Title: Category:Circulatory system
# Page ID: 10156905, Title: Category:Facial features
# Page ID: 2487650, Title: Category:Glands
# Page ID: 36703875, Title: Category:Human head and neck
# Page ID: 67211472, Title: Category:Human skin
# Page ID: 36058661, Title: Category:Human surface anatomy
# Page ID: 44532259, Title: Category:Limbs (anatomy)
# Page ID: 67910556, Title: Category:Human anatomy museums
# Page ID: 4244633, Title: Category:Neuroanatomy
# Page ID: 40496079, Title: Category:Human size
# Page ID: 5872296, Title: Category:Supernumerary body parts
# Page ID: 692430, Title: Category:Urinary system
#
# Fetching articles for category: Natural_sciences
# Page ID: 38890, Title: Natural science
# Page ID: 14541260, Title: Wikipedia:Contents/Natural and physical sciences
# Page ID: 33017018, Title: Outline of natural science
# Page ID: 62084284, Title: Anthropocene Working Group
# Page ID: 26242611, Title: Imperial College Faculty of Natural Sciences
# Page ID: 5449112, Title: Natural Sciences Collections Association
# Page ID: 43427, Title: Nature (journal)
# Page ID: 41751262, Title: Prodromus
# Page ID: 50283749, Title: Rangeland management
# Page ID: 37416480, Title: UPRRP College of Natural Sciences
# Page ID: 11013967, Title: Category:Natural scientists
# Page ID: 716903, Title: Category:Earth sciences
# Page ID: 47187374, Title: Category:Life sciences
# Page ID: 2054828, Title: Category:Natural history
# Page ID: 2106893, Title: Category:Physical sciences
# Page ID: 5612241, Title: Category:Natural science stubs
#
# Fetching articles for category: Social_sciences
# Page ID: 26781, Title: Social science
# Page ID: 1752697, Title: Template:Social sciences
# Page ID: 32988300, Title: Outline of social science
# Page ID: 54159957, Title: Administrative history
# Page ID: 2559736, Title: Animal studies
# Page ID: 21342679, Title: The arts and politics
# Page ID: 91869, Title: Ascribed characteristics
# Page ID: 3809916, Title: Bioculture
# Page ID: 60162699, Title: Change and continuity
# Page ID: 6252373, Title: Collective mental state
# Page ID: 40077102, Title: Computational social science
# Page ID: 34154970, Title: Criminology
# Page ID: 37961224, Title: Cultural studies
# Page ID: 74150552, Title: Data Colada
# Page ID: 125907, Title: Distributive justice
# Page ID: 10868061, Title: Doctor of Social Science
# Page ID: 60267122, Title: Efficient Voter Rule
# Page ID: 75482895, Title: Enchantment (social sciences)
# Page ID: 448199, Title: Force-field analysis
# Page ID: 18963910, Title: Geography
# Page ID: 12996884, Title: Gulbenkian commission
# Page ID: 59879020, Title: Health survival paradox
# Page ID: 13277470, Title: Heortology
# Page ID: 64674834, Title: Humanities, arts, and social sciences
# Page ID: 55147592, Title: International order
# Page ID: 16366, Title: Jurisprudence
# Page ID: 77164104, Title: Macro social work
# Page ID: 54044492, Title: Methodological nationalism
# Page ID: 33739475, Title: Mobilities
# Page ID: 66754592, Title: Modern Studies
# Page ID: 381564, Title: Normativity
# Page ID: 18841893, Title: Nudity
# Page ID: 74502376, Title: Nutritional psychiatry
# Page ID: 65629508, Title: Obshchestvovedeniye
# Page ID: 6937626, Title: Occupational science
# Page ID: 747363, Title: Operationalization
# Page ID: 2860038, Title: Paedology
# Page ID: 48818732, Title: Performance science
# Page ID: 62894863, Title: Platform capitalism
# Page ID: 424562, Title: Praxeology
# Page ID: 2118843, Title: Progress
# Page ID: 18973869, Title: Psychiatry
# Page ID: 59133650, Title: Quantum social science
# Page ID: 936059, Title: Representative sequences
# Page ID: 76608234, Title: Samhällsvetenskapsprogrammet
# Page ID: 411590, Title: Science and technology studies
# Page ID: 67638825, Title: Seriousness check
# Page ID: 3354877, Title: Social neuroscience
# Page ID: 194641, Title: Social services
# Page ID: 387746, Title: Social simulation
# Page ID: 201517, Title: Social studies
# Page ID: 146717, Title: Social work
# Page ID: 68255880, Title: Social work management
# Page ID: 44183472, Title: Spatial turn
# Page ID: 2518073, Title: Standard social science model
# Page ID: 1214879, Title: Visual anthropology
# Page ID: 63514664, Title: Visual ethnography
# Page ID: 77426940, Title: Vyavahāramālā
# Page ID: 13740771, Title: War studies
# Page ID: 192818, Title: Youth culture
# Page ID: 49827259, Title: Youth intervention
# Page ID: 77295120, Title: Youth services
# Page ID: 11432266, Title: Youth studies
# Page ID: 16990537, Title: Zemiology
# Page ID: 953917, Title: Category:Social scientists
# Page ID: 3743696, Title: Category:History of social sciences
# Page ID: 38172458, Title: Category:Philosophy of social science
# Page ID: 52064263, Title: Category:Social ideologies
# Page ID: 8996395, Title: Category:Social sciences awards
# Page ID: 46245372, Title: Category:Social science fiction
# Page ID: 13703638, Title: Category:Social sciences literature
# Page ID: 1003641, Title: Category:Social science occupations
# Page ID: 13703287, Title: Category:Social sciences organizations
# Page ID: 36873698, Title: Category:Social research
# Page ID: 23079219, Title: Category:Social theories
# Page ID: 13076019, Title: Category:Social sciences lists
# Page ID: 34920114, Title: Category:Social sciences terminology
# Page ID: 694863, Title: Category:Anthropology
# Page ID: 696279, Title: Category:Archaeology
# Page ID: 1592862, Title: Category:Behavioural sciences
# Page ID: 957793, Title: Category:Cognitive science
# Page ID: 7406890, Title: Category:Communication design
# Page ID: 60147353, Title: Category:Computational social science
# Page ID: 8865899, Title: Category:Computer-mediated communication
# Page ID: 3837110, Title: Category:Development studies
# Page ID: 60955139, Title: Category:Social science disambiguation pages
# Page ID: 700114, Title: Category:Economics
# Page ID: 11719938, Title: Category:Education theory
# Page ID: 24834079, Title: Category:Environmental social science
# Page ID: 40455234, Title: Category:Euthenics
# Page ID: 71310991, Title: Category:GLAM (culture and information)
# Page ID: 693555, Title: Category:History
# Page ID: 981229, Title: Category:Human development
# Page ID: 1111700, Title: Category:Human geography
# Page ID: 1090419, Title: Category:Human sciences
# Page ID: 74011153, Title: Category:Social science indices
# Page ID: 14230117, Title: Category:Labor studies
# Page ID: 70728001, Title: Category:Library and information science
# Page ID: 693798, Title: Category:Linguistics
# Page ID: 1733859, Title: Category:Media studies
# Page ID: 1437392, Title: Category:Military science
# Page ID: 75060334, Title: Category:Modern studies
# Page ID: 68459817, Title: Category:Network science
# Page ID: 21610733, Title: Category:Peace and conflict studies
# Page ID: 693803, Title: Category:Political science
# Page ID: 695868, Title: Category:Psychology
# Page ID: 2299819, Title: Category:Regional science
# Page ID: 20057313, Title: Category:Security studies
# Page ID: 57345235, Title: Category:Social physics
# Page ID: 42864745, Title: Category:Social science methodology
# Page ID: 699593, Title: Category:Sociology
# Page ID: 72427888, Title: Category:Thanatology
# Page ID: 705232, Title: Category:Urban planning
# Page ID: 54510618, Title: Category:Social science stubs
#
# Fetching articles for category: Psychology
# Page ID: 22921, Title: Psychology
# Page ID: 3401245, Title: Outline of psychology
# Page ID: 76393765, Title: Belief congruence
# Page ID: 71725016, Title: Collusion (psychology)
# Page ID: 35880263, Title: Counterphobic attitude
# Page ID: 10406, Title: Emotion
# Page ID: 154147, Title: Limerence
# Page ID: 75369294, Title: Masculine fragility
# Page ID: 232495, Title: Motivation
# Page ID: 77398814, Title: Musical escapism
# Page ID: 77736436, Title: My Dao method
# Page ID: 577886, Title: Nurture
# Page ID: 75381707, Title: Open Path Collective
# Page ID: 77014591, Title: Passionate and companionate love
# Page ID: 76676022, Title: Perceptual vigilance
# Page ID: 75377115, Title: Personality neuroscience
# Page ID: 72132, Title: Psychologist
# Page ID: 76199017, Title: Resilience week
# Page ID: 75123813, Title: Social buffering
# Page ID: 78224908, Title: The Type Mapping System
# Page ID: 8724310, Title: Three Principles Psychology
# Page ID: 77066704, Title: Vicarious mediation and vicarious functioning
# Page ID: 4163177, Title: Portal:Psychology
# Page ID: 2870944, Title: Category:Branches of psychology
# Page ID: 695886, Title: Category:Psychologists
# Page ID: 11307517, Title: Category:Psychology writers
# Page ID: 42216882, Title: Category:Works about psychology
# Page ID: 4391850, Title: Category:Psychology lists
# Page ID: 11331707, Title: Category:Psychology awards
# Page ID: 39024308, Title: Category:Psychological concepts
# Page ID: 70096991, Title: Category:Psychology controversies
# Page ID: 69375661, Title: Category:Psychology education
# Page ID: 54373666, Title: Category:Psychological effects
# Page ID: 691820, Title: Category:Emotion
# Page ID: 13047351, Title: Category:History of psychology
# Page ID: 53797375, Title: Category:Psychology images
# Page ID: 41394773, Title: Category:Psychological methodology
# Page ID: 4392117, Title: Category:Psychology organizations
# Page ID: 34271935, Title: Category:Philosophy of psychology
# Page ID: 1056200, Title: Category:Popular psychology
# Page ID: 2863840, Title: Category:Psychological schools
# Page ID: 77025121, Title: Category:Self-portraiture
# Page ID: 21331172, Title: Category:Sexual orientation and psychology
# Page ID: 15993560, Title: Category:Psychological testing
# Page ID: 2871214, Title: Category:Psychological theories
# Page ID: 18891575, Title: Category:Women and psychology
# Page ID: 1286297, Title: Category:Psychology stubs
# Page ID: 9686565, Title: Category:Psychology templates
# Page ID: 14169019, Title: Category:Psychology portal

# %% [markdown]
# ### save in csv file

# %%
import os
import csv
import requests

def sanitize_filename(title):
    """
    Sanitize the article title to create a valid filename.
    """
    invalid_chars = ['/', '\\', ':', '*', '?', '"', '<', '>', '|']
    for char in invalid_chars:
        title = title.replace(char, '_')
    return title

def save_article_to_csv(article, folder="data/original_data"):
    """
    Save a single article's title and content to a CSV file.
    """
    if not os.path.exists(folder):
        os.makedirs(folder)
    
    filename = sanitize_filename(article['title']) + ".csv"
    file_path = os.path.join(folder, filename)
    
    with open(file_path, mode="w", newline='', encoding="utf-8") as file:
        writer = csv.writer(file)
        writer.writerow(["Title", "Content"])  
        writer.writerow([article['title'], article['content']])  # Write title and content

def fetch_category_articles(category, limit=500):
    """
    Fetch articles from a specific Wikipedia category using the API.
    """
    url = f"https://en.wikipedia.org/w/api.php?action=query&list=categorymembers&cmtitle=Category:{category}&cmlimit={limit}&format=json"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        pages = data['query']['categorymembers']
        page_info = []
        for page in pages:
            page_info.append({'pageid': page['pageid'], 'title': page['title']})
        return page_info  # Return a list of dictionaries with 'pageid' and 'title'
    else:
        print(f"Failed to fetch pages for category {category}: {response.status_code}")
        return []

def fetch_page_content(pageid):
    """
    Fetch content of a Wikipedia page using the pageid.
    """
    url = f"https://en.wikipedia.org/w/api.php?action=query&pageids={pageid}&prop=extracts&explaintext&format=json"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        page = data['query']['pages'][str(pageid)]
        return page.get('extract', "No content available")
    else:
        return f"Failed to fetch content: {response.status_code}"

# Categories to fetch
categories = ["Medicine", "Medical_specialties", "Health_sciences", "Human_anatomy", "Natural_sciences", "Social_sciences", "Psychology"]

# Loop through each category and fetch article details
for category in categories:
    print(f"\nFetching articles for category: {category}")
    articles = fetch_category_articles(category)
    
    if articles:  # Only proceed if articles were fetched successfully
        for article in articles:
            print(f"Fetching content for article: {article['title']}")
            content = fetch_page_content(article['pageid'])
            article_data = {'title': article['title'], 'content': content}
            save_article_to_csv(article_data, folder="data/original_data")
            print(f"Article '{article['title']}' saved to CSV.")
    else:
        print(f"No articles found for category: {category}")
# Out:
# Fetching articles for category: Medicine
# Fetching content for article: Medicine
# Article 'Medicine' saved to CSV.
# Fetching content for article: Outline of medicine
# Article 'Outline of medicine' saved to CSV.
# Fetching content for article: Terminology of alternative medicine
# Article 'Terminology of alternative medicine' saved to CSV.
# Fetching content for article: Anti-aging medicine
# Article 'Anti-aging medicine' saved to CSV.
# Fetching content for article: Anti-asthmatic agent
# Article 'Anti-asthmatic agent' saved to CSV.
# Fetching content for article: Breastmilk medicine
# Article 'Breastmilk medicine' saved to CSV.
# Fetching content for article: Cancer exodus hypothesis
# Article 'Cancer exodus hypothesis' saved to CSV.
# Fetching content for article: Clinical handover
# Article 'Clinical handover' saved to CSV.
# Fetching content for article: Confocal endoscopy
# Article 'Confocal endoscopy' saved to CSV.
# Fetching content for article: Diabetes self-management
# Article 'Diabetes self-management' saved to CSV.
# Fetching content for article: Dorsal pancreatic agenesis
# Article 'Dorsal pancreatic agenesis' saved to CSV.
# Fetching content for article: Drone-Enhanced Emergency Medical Services
# Article 'Drone-Enhanced Emergency Medical Services' saved to CSV.
# Fetching content for article: Isotropic bands
# Article 'Isotropic bands' saved to CSV.
# Fetching content for article: LAMA2 related congenital muscular dystrophy
# Article 'LAMA2 related congenital muscular dystrophy' saved to CSV.
# Fetching content for article: List of forms of alternative medicine
# Article 'List of forms of alternative medicine' saved to CSV.
# Fetching content for article: LY-2365109
# Article 'LY-2365109' saved to CSV.
# Fetching content for article: Pediatric endocrinology
# Article 'Pediatric endocrinology' saved to CSV.
# Fetching content for article: Poison exon
# Article 'Poison exon' saved to CSV.
# Fetching content for article: RNU4-2 syndrome
# Article 'RNU4-2 syndrome' saved to CSV.
# Fetching content for article: Urinary anti-infective agent
# Article 'Urinary anti-infective agent' saved to CSV.
# Fetching content for article: Portal:Medicine
# Article 'Portal:Medicine' saved to CSV.
# Fetching content for article: Category:Medicine by city
# Article 'Category:Medicine by city' saved to CSV.
# Fetching content for article: Category:Medicine by country
# Article 'Category:Medicine by country' saved to CSV.
# Fetching content for article: Category:Medicine by country subdivision
# Article 'Category:Medicine by country subdivision' saved to CSV.
# Fetching content for article: Category:Medicine by dependent territory
# Article 'Category:Medicine by dependent territory' saved to CSV.
# Fetching content for article: Category:Medicine by century
# Article 'Category:Medicine by century' saved to CSV.
# Fetching content for article: Category:Medicine by decade
# Article 'Category:Medicine by decade' saved to CSV.
# Fetching content for article: Category:Medicine by year
# Article 'Category:Medicine by year' saved to CSV.
# Fetching content for article: Category:Alternative medicine
# Article 'Category:Alternative medicine' saved to CSV.
# Fetching content for article: Category:Clinical medicine
# Article 'Category:Clinical medicine' saved to CSV.
# Fetching content for article: Category:Veterinary medicine
# Article 'Category:Veterinary medicine' saved to CSV.
# Fetching content for article: Category:Medical lists
# Article 'Category:Medical lists' saved to CSV.
# Fetching content for article: Category:Works about medicine
# Article 'Category:Works about medicine' saved to CSV.
# Fetching content for article: Category:Medical activism
# Article 'Category:Medical activism' saved to CSV.
# Fetching content for article: Category:Medical associations
# Article 'Category:Medical associations' saved to CSV.
# Fetching content for article: Category:Medicine awards
# Article 'Category:Medicine awards' saved to CSV.
# Fetching content for article: Category:Cause (medicine)
# Article 'Category:Cause (medicine)' saved to CSV.
# Fetching content for article: Category:Chemicals in medicine
# Article 'Category:Chemicals in medicine' saved to CSV.
# Fetching content for article: Category:Health-related conspiracy theories
# Article 'Category:Health-related conspiracy theories' saved to CSV.
# Fetching content for article: Category:Medical aspects of death
# Article 'Category:Medical aspects of death' saved to CSV.
# Fetching content for article: Category:Medical diplomacy
# Article 'Category:Medical diplomacy' saved to CSV.
# Fetching content for article: Category:Medical education
# Article 'Category:Medical education' saved to CSV.
# Fetching content for article: Category:History of medicine
# Article 'Category:History of medicine' saved to CSV.
# Fetching content for article: Category:Medical humanities
# Article 'Category:Medical humanities' saved to CSV.
# Fetching content for article: Category:Intersex and medicine
# Article 'Category:Intersex and medicine' saved to CSV.
# Fetching content for article: Category:Medical and health organizations
# Article 'Category:Medical and health organizations' saved to CSV.
# Fetching content for article: Category:Medical phenomena
# Article 'Category:Medical phenomena' saved to CSV.
# Fetching content for article: Category:Practice of medicine
# Article 'Category:Practice of medicine' saved to CSV.
# Fetching content for article: Category:Prescription of drugs
# Article 'Category:Prescription of drugs' saved to CSV.
# Fetching content for article: Category:Medical prevention
# Article 'Category:Medical prevention' saved to CSV.
# Fetching content for article: Category:Religion and medicine
# Article 'Category:Religion and medicine' saved to CSV.
# Fetching content for article: Category:Medical research
# Article 'Category:Medical research' saved to CSV.
# Fetching content for article: Category:Medicine in society
# Article 'Category:Medicine in society' saved to CSV.
# Fetching content for article: Category:Medical symbols
# Article 'Category:Medical symbols' saved to CSV.
# Fetching content for article: Category:Medical technology
# Article 'Category:Medical technology' saved to CSV.
# Fetching content for article: Category:Medical terminology
# Article 'Category:Medical terminology' saved to CSV.
# Fetching content for article: Category:Theory of medicine
# Article 'Category:Theory of medicine' saved to CSV.
# Fetching content for article: Category:Medical volunteerism
# Article 'Category:Medical volunteerism' saved to CSV.
# Fetching content for article: Category:Women in medicine
# Article 'Category:Women in medicine' saved to CSV.
# Fetching content for article: Category:Medicine stubs
# Article 'Category:Medicine stubs' saved to CSV.
#
# Fetching articles for category: Medical_specialties
# Fetching content for article: Medical specialty
# Article 'Medical specialty' saved to CSV.
# Fetching content for article: Allergist
# Article 'Allergist' saved to CSV.
# Fetching content for article: Arthrology
# Article 'Arthrology' saved to CSV.
# Fetching content for article: Civil surgeon
# Article 'Civil surgeon' saved to CSV.
# Fetching content for article: Clinical physiology
# Article 'Clinical physiology' saved to CSV.
# Fetching content for article: Conflict and Catastrophe Medicine
# Article 'Conflict and Catastrophe Medicine' saved to CSV.
# Fetching content for article: Diving Medical Examiner
# Article 'Diving Medical Examiner' saved to CSV.
# Fetching content for article: Diving Medical Practitioner
# Article 'Diving Medical Practitioner' saved to CSV.
# Fetching content for article: Diving medicine
# Article 'Diving medicine' saved to CSV.
# Fetching content for article: Environmental medicine
# Article 'Environmental medicine' saved to CSV.
# Fetching content for article: Exercise medicine
# Article 'Exercise medicine' saved to CSV.
# Fetching content for article: Mass gathering medicine
# Article 'Mass gathering medicine' saved to CSV.
# Fetching content for article: Medical entomology
# Article 'Medical entomology' saved to CSV.
# Fetching content for article: List of medical specialty colleges in the United States
# Article 'List of medical specialty colleges in the United States' saved to CSV.
# Fetching content for article: Medical statistics
# Article 'Medical statistics' saved to CSV.
# Fetching content for article: Neurosurgical anesthesia
# Article 'Neurosurgical anesthesia' saved to CSV.
# Fetching content for article: Occupational medicine
# Article 'Occupational medicine' saved to CSV.
# Fetching content for article: Oncology
# Article 'Oncology' saved to CSV.
# Fetching content for article: Oral and maxillofacial surgery
# Article 'Oral and maxillofacial surgery' saved to CSV.
# Fetching content for article: Otorhinolaryngology
# Article 'Otorhinolaryngology' saved to CSV.
# Fetching content for article: Parasitology
# Article 'Parasitology' saved to CSV.
# Fetching content for article: Phoniatrics
# Article 'Phoniatrics' saved to CSV.
# Fetching content for article: Plastic surgery
# Article 'Plastic surgery' saved to CSV.
# Fetching content for article: Psychosomatic medicine
# Article 'Psychosomatic medicine' saved to CSV.
# Fetching content for article: Railway surgery
# Article 'Railway surgery' saved to CSV.
# Fetching content for article: Rural health
# Article 'Rural health' saved to CSV.
# Fetching content for article: Subspecialty
# Article 'Subspecialty' saved to CSV.
# Fetching content for article: Travel medicine
# Article 'Travel medicine' saved to CSV.
# Fetching content for article: Triological Society
# Article 'Triological Society' saved to CSV.
# Fetching content for article: Venereology
# Article 'Venereology' saved to CSV.
# Fetching content for article: Category:Branches of medical specialties
# Article 'Category:Branches of medical specialties' saved to CSV.
# Fetching content for article: Category:Medical doctors by specialty
# Article 'Category:Medical doctors by specialty' saved to CSV.
# Fetching content for article: Category:Nursing specialties
# Article 'Category:Nursing specialties' saved to CSV.
# Fetching content for article: Category:History of medical and surgical specialties
# Article 'Category:History of medical and surgical specialties' saved to CSV.
# Fetching content for article: Category:Interdisciplinary subfields of medicine
# Article 'Category:Interdisciplinary subfields of medicine' saved to CSV.
# Fetching content for article: Category:Medical and health organizations by subject
# Article 'Category:Medical and health organizations by subject' saved to CSV.
# Fetching content for article: Category:Medical education by branch
# Article 'Category:Medical education by branch' saved to CSV.
# Fetching content for article: Category:Medical literature by subject
# Article 'Category:Medical literature by subject' saved to CSV.
# Fetching content for article: Category:Addiction medicine
# Article 'Category:Addiction medicine' saved to CSV.
# Fetching content for article: Category:Andrology
# Article 'Category:Andrology' saved to CSV.
# Fetching content for article: Category:Anesthesiology
# Article 'Category:Anesthesiology' saved to CSV.
# Fetching content for article: Category:Angiology
# Article 'Category:Angiology' saved to CSV.
# Fetching content for article: Category:Arthrology
# Article 'Category:Arthrology' saved to CSV.
# Fetching content for article: Category:Audiology
# Article 'Category:Audiology' saved to CSV.
# Fetching content for article: Category:Aviation medicine
# Article 'Category:Aviation medicine' saved to CSV.
# Fetching content for article: Category:Biomedicine
# Article 'Category:Biomedicine' saved to CSV.
# Fetching content for article: Category:Cardiology
# Article 'Category:Cardiology' saved to CSV.
# Fetching content for article: Category:Dentistry
# Article 'Category:Dentistry' saved to CSV.
# Fetching content for article: Category:Dermatology
# Article 'Category:Dermatology' saved to CSV.
# Fetching content for article: Category:Emergency medicine
# Article 'Category:Emergency medicine' saved to CSV.
# Fetching content for article: Category:Endocrinology
# Article 'Category:Endocrinology' saved to CSV.
# Fetching content for article: Category:Gastroenterology
# Article 'Category:Gastroenterology' saved to CSV.
# Fetching content for article: Category:General practice
# Article 'Category:General practice' saved to CSV.
# Fetching content for article: Category:Medical genetics
# Article 'Category:Medical genetics' saved to CSV.
# Fetching content for article: Category:Geriatrics
# Article 'Category:Geriatrics' saved to CSV.
# Fetching content for article: Category:Gynaecology
# Article 'Category:Gynaecology' saved to CSV.
# Fetching content for article: Category:Hematology
# Article 'Category:Hematology' saved to CSV.
# Fetching content for article: Category:Hepatology
# Article 'Category:Hepatology' saved to CSV.
# Fetching content for article: Category:Hospital medicine
# Article 'Category:Hospital medicine' saved to CSV.
# Fetching content for article: Category:Immunology
# Article 'Category:Immunology' saved to CSV.
# Fetching content for article: Category:Intensive care medicine
# Article 'Category:Intensive care medicine' saved to CSV.
# Fetching content for article: Category:Internal medicine
# Article 'Category:Internal medicine' saved to CSV.
# Fetching content for article: Category:Men's health
# Article 'Category:Men's health' saved to CSV.
# Fetching content for article: Category:Medical microbiology
# Article 'Category:Medical microbiology' saved to CSV.
# Fetching content for article: Category:Military medicine
# Article 'Category:Military medicine' saved to CSV.
# Fetching content for article: Category:Nephrology
# Article 'Category:Nephrology' saved to CSV.
# Fetching content for article: Category:Neurology
# Article 'Category:Neurology' saved to CSV.
# Fetching content for article: Category:Nuclear medicine
# Article 'Category:Nuclear medicine' saved to CSV.
# Fetching content for article: Category:Obstetrics
# Article 'Category:Obstetrics' saved to CSV.
# Fetching content for article: Category:Occupational medicine
# Article 'Category:Occupational medicine' saved to CSV.
# Fetching content for article: Category:Oncology
# Article 'Category:Oncology' saved to CSV.
# Fetching content for article: Category:Ophthalmology
# Article 'Category:Ophthalmology' saved to CSV.
# Fetching content for article: Category:Orthopedics
# Article 'Category:Orthopedics' saved to CSV.
# Fetching content for article: Category:Otorhinolaryngology
# Article 'Category:Otorhinolaryngology' saved to CSV.
# Fetching content for article: Category:Parasitology
# Article 'Category:Parasitology' saved to CSV.
# Fetching content for article: Category:Pathology
# Article 'Category:Pathology' saved to CSV.
# Fetching content for article: Category:Pediatrics
# Article 'Category:Pediatrics' saved to CSV.
# Fetching content for article: Category:Clinical pharmacology
# Article 'Category:Clinical pharmacology' saved to CSV.
# Fetching content for article: Category:Podiatry
# Article 'Category:Podiatry' saved to CSV.
# Fetching content for article: Category:Preventive medicine
# Article 'Category:Preventive medicine' saved to CSV.
# Fetching content for article: Category:Prison healthcare
# Article 'Category:Prison healthcare' saved to CSV.
# Fetching content for article: Category:Psychiatry
# Article 'Category:Psychiatry' saved to CSV.
# Fetching content for article: Category:Public health
# Article 'Category:Public health' saved to CSV.
# Fetching content for article: Category:Pulmonology
# Article 'Category:Pulmonology' saved to CSV.
# Fetching content for article: Category:Radiology
# Article 'Category:Radiology' saved to CSV.
# Fetching content for article: Category:Railway surgery
# Article 'Category:Railway surgery' saved to CSV.
# Fetching content for article: Category:Rehabilitation medicine
# Article 'Category:Rehabilitation medicine' saved to CSV.
# Fetching content for article: Category:Rheumatology
# Article 'Category:Rheumatology' saved to CSV.
# Fetching content for article: Category:Sexual health
# Article 'Category:Sexual health' saved to CSV.
# Fetching content for article: Category:Sleep medicine
# Article 'Category:Sleep medicine' saved to CSV.
# Fetching content for article: Category:Space medicine
# Article 'Category:Space medicine' saved to CSV.
# Fetching content for article: Category:Sports medicine
# Article 'Category:Sports medicine' saved to CSV.
# Fetching content for article: Category:Medical statistics
# Article 'Category:Medical statistics' saved to CSV.
# Fetching content for article: Category:Stomatologists
# Article 'Category:Stomatologists' saved to CSV.
# Fetching content for article: Category:Surgery
# Article 'Category:Surgery' saved to CSV.
# Fetching content for article: Category:Thermal medicine
# Article 'Category:Thermal medicine' saved to CSV.
# Fetching content for article: Category:Toxicology
# Article 'Category:Toxicology' saved to CSV.
# Fetching content for article: Category:Transplantation medicine
# Article 'Category:Transplantation medicine' saved to CSV.
# Fetching content for article: Category:Tropical medicine
# Article 'Category:Tropical medicine' saved to CSV.
# Fetching content for article: Category:Urology
# Article 'Category:Urology' saved to CSV.
# Fetching content for article: Category:Women's health
# Article 'Category:Women's health' saved to CSV.
#
# Fetching articles for category: Health_sciences
# Fetching content for article: Outline of health sciences
# Article 'Outline of health sciences' saved to CSV.
# Fetching content for article: Anthropomaximology
# Article 'Anthropomaximology' saved to CSV.
# Fetching content for article: Biomedical sciences
# Article 'Biomedical sciences' saved to CSV.
# Fetching content for article: Epidemiology
# Article 'Epidemiology' saved to CSV.
# Fetching content for article: Global health
# Article 'Global health' saved to CSV.
# Fetching content for article: Health care
# Article 'Health care' saved to CSV.
# Fetching content for article: Health crisis
# Article 'Health crisis' saved to CSV.
# Fetching content for article: Health equity
# Article 'Health equity' saved to CSV.
# Fetching content for article: Health policy
# Article 'Health policy' saved to CSV.
# Fetching content for article: Health Sciences Descriptors
# Article 'Health Sciences Descriptors' saved to CSV.
# Fetching content for article: Health system
# Article 'Health system' saved to CSV.
# Fetching content for article: Population health
# Article 'Population health' saved to CSV.
# Fetching content for article: Positive health
# Article 'Positive health' saved to CSV.
# Fetching content for article: Public health
# Article 'Public health' saved to CSV.
# Fetching content for article: Publicly funded health care
# Article 'Publicly funded health care' saved to CSV.
# Fetching content for article: Right to health
# Article 'Right to health' saved to CSV.
# Fetching content for article: Universal health care
# Article 'Universal health care' saved to CSV.
# Fetching content for article: Category:Health sciences by country
# Article 'Category:Health sciences by country' saved to CSV.
# Fetching content for article: Category:Medicine
# Article 'Category:Medicine' saved to CSV.
# Fetching content for article: Category:Academic health science centres
# Article 'Category:Academic health science centres' saved to CSV.
# Fetching content for article: Category:Audiology
# Article 'Category:Audiology' saved to CSV.
# Fetching content for article: Category:Auxology
# Article 'Category:Auxology' saved to CSV.
# Fetching content for article: Category:Biological engineering
# Article 'Category:Biological engineering' saved to CSV.
# Fetching content for article: Category:Biotechnology
# Article 'Category:Biotechnology' saved to CSV.
# Fetching content for article: Category:Dentistry
# Article 'Category:Dentistry' saved to CSV.
# Fetching content for article: Category:Epidemiology
# Article 'Category:Epidemiology' saved to CSV.
# Fetching content for article: Category:Health physicists
# Article 'Category:Health physicists' saved to CSV.
# Fetching content for article: Category:ILAE Wikipedia Project
# Article 'Category:ILAE Wikipedia Project' saved to CSV.
# Fetching content for article: Category:Medical research
# Article 'Category:Medical research' saved to CSV.
# Fetching content for article: Category:Midwifery
# Article 'Category:Midwifery' saved to CSV.
# Fetching content for article: Category:Nursing
# Article 'Category:Nursing' saved to CSV.
# Fetching content for article: Category:Health sciences organizations
# Article 'Category:Health sciences organizations' saved to CSV.
# Fetching content for article: Category:Pharmaceutical sciences
# Article 'Category:Pharmaceutical sciences' saved to CSV.
# Fetching content for article: Category:Pharmacy
# Article 'Category:Pharmacy' saved to CSV.
# Fetching content for article: Category:Health sciences publications
# Article 'Category:Health sciences publications' saved to CSV.
# Fetching content for article: Category:Public health
# Article 'Category:Public health' saved to CSV.
# Fetching content for article: Category:Health sciences schools
# Article 'Category:Health sciences schools' saved to CSV.
# Fetching content for article: Category:Seventh-day Adventists in health science
# Article 'Category:Seventh-day Adventists in health science' saved to CSV.
# Fetching content for article: Category:Social work
# Article 'Category:Social work' saved to CSV.
# Fetching content for article: Category:Translational medicine
# Article 'Category:Translational medicine' saved to CSV.
# Fetching content for article: Category:Veterinary medicine
# Article 'Category:Veterinary medicine' saved to CSV.
#
# Fetching articles for category: Human_anatomy
# Fetching content for article: Human body
# Article 'Human body' saved to CSV.
# Fetching content for article: List of anatomy mnemonics
# Article 'List of anatomy mnemonics' saved to CSV.
# Fetching content for article: Outline of the human nervous system
# Article 'Outline of the human nervous system' saved to CSV.
# Fetching content for article: Abdomen
# Article 'Abdomen' saved to CSV.
# Fetching content for article: Achilles tendon
# Article 'Achilles tendon' saved to CSV.
# Fetching content for article: Adductor hiatus
# Article 'Adductor hiatus' saved to CSV.
# Fetching content for article: Alveolus
# Article 'Alveolus' saved to CSV.
# Fetching content for article: Amniotic sac
# Article 'Amniotic sac' saved to CSV.
# Fetching content for article: Anatomical terminology
# Article 'Anatomical terminology' saved to CSV.
# Fetching content for article: Anatomical terms of bone
# Article 'Anatomical terms of bone' saved to CSV.
# Fetching content for article: Anatomical terms of muscle
# Article 'Anatomical terms of muscle' saved to CSV.
# Fetching content for article: Anatomical terms of neuroanatomy
# Article 'Anatomical terms of neuroanatomy' saved to CSV.
# Fetching content for article: Anatomy Charts of the Arabs
# Article 'Anatomy Charts of the Arabs' saved to CSV.
# Fetching content for article: Anatomy of human
# Article 'Anatomy of human' saved to CSV.
# Fetching content for article: Anorectal canal
# Article 'Anorectal canal' saved to CSV.
# Fetching content for article: Anthropometry
# Article 'Anthropometry' saved to CSV.
# Fetching content for article: Aortopulmonary space
# Article 'Aortopulmonary space' saved to CSV.
# Fetching content for article: Ape hand deformity
# Article 'Ape hand deformity' saved to CSV.
# Fetching content for article: Apollo's belt
# Article 'Apollo's belt' saved to CSV.
# Fetching content for article: Axial skeleton
# Article 'Axial skeleton' saved to CSV.
# Fetching content for article: Beclard Triangle
# Article 'Beclard Triangle' saved to CSV.
# Fetching content for article: The body in traditional Chinese medicine
# Article 'The body in traditional Chinese medicine' saved to CSV.
# Fetching content for article: Body Worlds
# Article 'Body Worlds' saved to CSV.
# Fetching content for article: Brain connectivity estimators
# Article 'Brain connectivity estimators' saved to CSV.
# Fetching content for article: Bregma
# Article 'Bregma' saved to CSV.
# Fetching content for article: Cavoatrial junction
# Article 'Cavoatrial junction' saved to CSV.
# Fetching content for article: Center for Anatomy of the Charité
# Article 'Center for Anatomy of the Charité' saved to CSV.
# Fetching content for article: Cervical artery dissection
# Article 'Cervical artery dissection' saved to CSV.
# Fetching content for article: Cervical rib
# Article 'Cervical rib' saved to CSV.
# Fetching content for article: Coccygeal glomus
# Article 'Coccygeal glomus' saved to CSV.
# Fetching content for article: Compensatory growth (organ)
# Article 'Compensatory growth (organ)' saved to CSV.
# Fetching content for article: Composition of the human body
# Article 'Composition of the human body' saved to CSV.
# Fetching content for article: Corona of glans penis
# Article 'Corona of glans penis' saved to CSV.
# Fetching content for article: Darwin's tubercle
# Article 'Darwin's tubercle' saved to CSV.
# Fetching content for article: Dental anatomy
# Article 'Dental anatomy' saved to CSV.
# Fetching content for article: Dermatocranium
# Article 'Dermatocranium' saved to CSV.
# Fetching content for article: Desjardins' point
# Article 'Desjardins' point' saved to CSV.
# Fetching content for article: Dorsal body cavity
# Article 'Dorsal body cavity' saved to CSV.
# Fetching content for article: Eardrum
# Article 'Eardrum' saved to CSV.
# Fetching content for article: Endocranium
# Article 'Endocranium' saved to CSV.
# Fetching content for article: Episternal ossicles
# Article 'Episternal ossicles' saved to CSV.
# Fetching content for article: Estrogenic fat
# Article 'Estrogenic fat' saved to CSV.
# Fetching content for article: Eustachian tube
# Article 'Eustachian tube' saved to CSV.
# Fetching content for article: Evelyn tables
# Article 'Evelyn tables' saved to CSV.
# Fetching content for article: Extensor retinaculum of the hand
# Article 'Extensor retinaculum of the hand' saved to CSV.
# Fetching content for article: Eyelid
# Article 'Eyelid' saved to CSV.
# Fetching content for article: Fascial Net Plastination Project
# Article 'Fascial Net Plastination Project' saved to CSV.
# Fetching content for article: Fascial spaces of the head and neck
# Article 'Fascial spaces of the head and neck' saved to CSV.
# Fetching content for article: Fingerprint
# Article 'Fingerprint' saved to CSV.
# Fetching content for article: Fontanelle
# Article 'Fontanelle' saved to CSV.
# Fetching content for article: Foramen singulare
# Article 'Foramen singulare' saved to CSV.
# Fetching content for article: Foreskin
# Article 'Foreskin' saved to CSV.
# Fetching content for article: Fossa navicularis magna
# Article 'Fossa navicularis magna' saved to CSV.
# Fetching content for article: Glabella
# Article 'Glabella' saved to CSV.
# Fetching content for article: Groin
# Article 'Groin' saved to CSV.
# Fetching content for article: Growing teeth
# Article 'Growing teeth' saved to CSV.
# Fetching content for article: Heterocrine gland
# Article 'Heterocrine gland' saved to CSV.
# Fetching content for article: Outline of human anatomy
# Article 'Outline of human anatomy' saved to CSV.
# Fetching content for article: Human back
# Article 'Human back' saved to CSV.
# Fetching content for article: Human fat
# Article 'Human fat' saved to CSV.
# Fetching content for article: Human mouth
# Article 'Human mouth' saved to CSV.
# Fetching content for article: Human nose
# Article 'Human nose' saved to CSV.
# Fetching content for article: Human penis
# Article 'Human penis' saved to CSV.
# Fetching content for article: Human reproductive system
# Article 'Human reproductive system' saved to CSV.
# Fetching content for article: Human skeleton
# Article 'Human skeleton' saved to CSV.
# Fetching content for article: Human tooth
# Article 'Human tooth' saved to CSV.
# Fetching content for article: Human vestigiality
# Article 'Human vestigiality' saved to CSV.
# Fetching content for article: Iliac crest
# Article 'Iliac crest' saved to CSV.
# Fetching content for article: Inferior frontal junction
# Article 'Inferior frontal junction' saved to CSV.
# Fetching content for article: Institute of Human Anatomy
# Article 'Institute of Human Anatomy' saved to CSV.
# Fetching content for article: Interdental plate
# Article 'Interdental plate' saved to CSV.
# Fetching content for article: Interoception
# Article 'Interoception' saved to CSV.
# Fetching content for article: Intrascleral plexus
# Article 'Intrascleral plexus' saved to CSV.
# Fetching content for article: Kiesselbach's plexus
# Article 'Kiesselbach's plexus' saved to CSV.
# Fetching content for article: Kinanthropometry
# Article 'Kinanthropometry' saved to CSV.
# Fetching content for article: Koch's triangle
# Article 'Koch's triangle' saved to CSV.
# Fetching content for article: Lap
# Article 'Lap' saved to CSV.
# Fetching content for article: Lateral palpebral raphe
# Article 'Lateral palpebral raphe' saved to CSV.
# Fetching content for article: Lip
# Article 'Lip' saved to CSV.
# Fetching content for article: Little finger
# Article 'Little finger' saved to CSV.
# Fetching content for article: Marginal sinus
# Article 'Marginal sinus' saved to CSV.
# Fetching content for article: Marionette lines
# Article 'Marionette lines' saved to CSV.
# Fetching content for article: Mentum
# Article 'Mentum' saved to CSV.
# Fetching content for article: Middle ear
# Article 'Middle ear' saved to CSV.
# Fetching content for article: Neanderthal anatomy
# Article 'Neanderthal anatomy' saved to CSV.
# Fetching content for article: Neurocranium
# Article 'Neurocranium' saved to CSV.
# Fetching content for article: Neuroepigenetics
# Article 'Neuroepigenetics' saved to CSV.
# Fetching content for article: Palmar aponeurosis
# Article 'Palmar aponeurosis' saved to CSV.
# Fetching content for article: Pectoral muscles
# Article 'Pectoral muscles' saved to CSV.
# Fetching content for article: Pelvic tilt
# Article 'Pelvic tilt' saved to CSV.
# Fetching content for article: Petrous portion
# Article 'Petrous portion' saved to CSV.
# Fetching content for article: Ptosis (chin)
# Article 'Ptosis (chin)' saved to CSV.
# Fetching content for article: Radiographic anatomy
# Article 'Radiographic anatomy' saved to CSV.
# Fetching content for article: Rhombus of Michaelis
# Article 'Rhombus of Michaelis' saved to CSV.
# Fetching content for article: Scalene muscles
# Article 'Scalene muscles' saved to CSV.
# Fetching content for article: Skin fold
# Article 'Skin fold' saved to CSV.
# Fetching content for article: Splanchnocranium
# Article 'Splanchnocranium' saved to CSV.
# Fetching content for article: Stafne bone cavity
# Article 'Stafne bone cavity' saved to CSV.
# Fetching content for article: Sternal foramen
# Article 'Sternal foramen' saved to CSV.
# Fetching content for article: Superficial cervical fascia
# Article 'Superficial cervical fascia' saved to CSV.
# Fetching content for article: Superior thoracic aperture
# Article 'Superior thoracic aperture' saved to CSV.
# Fetching content for article: Surface anatomy
# Article 'Surface anatomy' saved to CSV.
# Fetching content for article: Table of epithelia of human organs
# Article 'Table of epithelia of human organs' saved to CSV.
# Fetching content for article: Terminologia Anatomica
# Article 'Terminologia Anatomica' saved to CSV.
# Fetching content for article: Terry Collection
# Article 'Terry Collection' saved to CSV.
# Fetching content for article: Trochanter
# Article 'Trochanter' saved to CSV.
# Fetching content for article: Tubercle
# Article 'Tubercle' saved to CSV.
# Fetching content for article: Vena comitans
# Article 'Vena comitans' saved to CSV.
# Fetching content for article: Vesicouterine pouch
# Article 'Vesicouterine pouch' saved to CSV.
# Fetching content for article: Viscerocranium
# Article 'Viscerocranium' saved to CSV.
# Fetching content for article: Visible Embryo Project
# Article 'Visible Embryo Project' saved to CSV.
# Fetching content for article: Visible Human Project
# Article 'Visible Human Project' saved to CSV.
# Fetching content for article: Wenis
# Article 'Wenis' saved to CSV.
# Fetching content for article: Category:Human anatomy by organ
# Article 'Category:Human anatomy by organ' saved to CSV.
# Fetching content for article: Category:Human anatomy by system
# Article 'Category:Human anatomy by system' saved to CSV.
# Fetching content for article: Category:Anthropometry
# Article 'Category:Anthropometry' saved to CSV.
# Fetching content for article: Category:Lists of human anatomical features
# Article 'Category:Lists of human anatomical features' saved to CSV.
# Fetching content for article: Category:Absent body parts
# Article 'Category:Absent body parts' saved to CSV.
# Fetching content for article: Category:Amniotic sac
# Article 'Category:Amniotic sac' saved to CSV.
# Fetching content for article: Category:Anatomical variations
# Article 'Category:Anatomical variations' saved to CSV.
# Fetching content for article: Category:Anatomy named for one who described it
# Article 'Category:Anatomy named for one who described it' saved to CSV.
# Fetching content for article: Category:Back anatomy
# Article 'Category:Back anatomy' saved to CSV.
# Fetching content for article: Category:Circulatory system
# Article 'Category:Circulatory system' saved to CSV.
# Fetching content for article: Category:Facial features
# Article 'Category:Facial features' saved to CSV.
# Fetching content for article: Category:Glands
# Article 'Category:Glands' saved to CSV.
# Fetching content for article: Category:Human head and neck
# Article 'Category:Human head and neck' saved to CSV.
# Fetching content for article: Category:Human skin
# Article 'Category:Human skin' saved to CSV.
# Fetching content for article: Category:Human surface anatomy
# Article 'Category:Human surface anatomy' saved to CSV.
# Fetching content for article: Category:Limbs (anatomy)
# Article 'Category:Limbs (anatomy)' saved to CSV.
# Fetching content for article: Category:Human anatomy museums
# Article 'Category:Human anatomy museums' saved to CSV.
# Fetching content for article: Category:Neuroanatomy
# Article 'Category:Neuroanatomy' saved to CSV.
# Fetching content for article: Category:Human size
# Article 'Category:Human size' saved to CSV.
# Fetching content for article: Category:Supernumerary body parts
# Article 'Category:Supernumerary body parts' saved to CSV.
# Fetching content for article: Category:Urinary system
# Article 'Category:Urinary system' saved to CSV.
#
# Fetching articles for category: Natural_sciences
# Fetching content for article: Natural science
# Article 'Natural science' saved to CSV.
# Fetching content for article: Wikipedia:Contents/Natural and physical sciences
# Article 'Wikipedia:Contents/Natural and physical sciences' saved to CSV.
# Fetching content for article: Outline of natural science
# Article 'Outline of natural science' saved to CSV.
# Fetching content for article: Anthropocene Working Group
# Article 'Anthropocene Working Group' saved to CSV.
# Fetching content for article: Imperial College Faculty of Natural Sciences
# Article 'Imperial College Faculty of Natural Sciences' saved to CSV.
# Fetching content for article: Natural Sciences Collections Association
# Article 'Natural Sciences Collections Association' saved to CSV.
# Fetching content for article: Nature (journal)
# Article 'Nature (journal)' saved to CSV.
# Fetching content for article: Prodromus
# Article 'Prodromus' saved to CSV.
# Fetching content for article: Rangeland management
# Article 'Rangeland management' saved to CSV.
# Fetching content for article: UPRRP College of Natural Sciences
# Article 'UPRRP College of Natural Sciences' saved to CSV.
# Fetching content for article: Category:Natural scientists
# Article 'Category:Natural scientists' saved to CSV.
# Fetching content for article: Category:Earth sciences
# Article 'Category:Earth sciences' saved to CSV.
# Fetching content for article: Category:Life sciences
# Article 'Category:Life sciences' saved to CSV.
# Fetching content for article: Category:Natural history
# Article 'Category:Natural history' saved to CSV.
# Fetching content for article: Category:Physical sciences
# Article 'Category:Physical sciences' saved to CSV.
# Fetching content for article: Category:Natural science stubs
# Article 'Category:Natural science stubs' saved to CSV.
#
# Fetching articles for category: Social_sciences
# Fetching content for article: Social science
# Article 'Social science' saved to CSV.
# Fetching content for article: Template:Social sciences
# Article 'Template:Social sciences' saved to CSV.
# Fetching content for article: Outline of social science
# Article 'Outline of social science' saved to CSV.
# Fetching content for article: Administrative history
# Article 'Administrative history' saved to CSV.
# Fetching content for article: Animal studies
# Article 'Animal studies' saved to CSV.
# Fetching content for article: The arts and politics
# Article 'The arts and politics' saved to CSV.
# Fetching content for article: Ascribed characteristics
# Article 'Ascribed characteristics' saved to CSV.
# Fetching content for article: Bioculture
# Article 'Bioculture' saved to CSV.
# Fetching content for article: Change and continuity
# Article 'Change and continuity' saved to CSV.
# Fetching content for article: Collective mental state
# Article 'Collective mental state' saved to CSV.
# Fetching content for article: Computational social science
# Article 'Computational social science' saved to CSV.
# Fetching content for article: Criminology
# Article 'Criminology' saved to CSV.
# Fetching content for article: Cultural studies
# Article 'Cultural studies' saved to CSV.
# Fetching content for article: Data Colada
# Article 'Data Colada' saved to CSV.
# Fetching content for article: Distributive justice
# Article 'Distributive justice' saved to CSV.
# Fetching content for article: Doctor of Social Science
# Article 'Doctor of Social Science' saved to CSV.
# Fetching content for article: Efficient Voter Rule
# Article 'Efficient Voter Rule' saved to CSV.
# Fetching content for article: Enchantment (social sciences)
# Article 'Enchantment (social sciences)' saved to CSV.
# Fetching content for article: Force-field analysis
# Article 'Force-field analysis' saved to CSV.
# Fetching content for article: Geography
# Article 'Geography' saved to CSV.
# Fetching content for article: Gulbenkian commission
# Article 'Gulbenkian commission' saved to CSV.
# Fetching content for article: Health survival paradox
# Article 'Health survival paradox' saved to CSV.
# Fetching content for article: Heortology
# Article 'Heortology' saved to CSV.
# Fetching content for article: Humanities, arts, and social sciences
# Article 'Humanities, arts, and social sciences' saved to CSV.
# Fetching content for article: International order
# Article 'International order' saved to CSV.
# Fetching content for article: Jurisprudence
# Article 'Jurisprudence' saved to CSV.
# Fetching content for article: Macro social work
# Article 'Macro social work' saved to CSV.
# Fetching content for article: Methodological nationalism
# Article 'Methodological nationalism' saved to CSV.
# Fetching content for article: Mobilities
# Article 'Mobilities' saved to CSV.
# Fetching content for article: Modern Studies
# Article 'Modern Studies' saved to CSV.
# Fetching content for article: Normativity
# Article 'Normativity' saved to CSV.
# Fetching content for article: Nudity
# Article 'Nudity' saved to CSV.
# Fetching content for article: Nutritional psychiatry
# Article 'Nutritional psychiatry' saved to CSV.
# Fetching content for article: Obshchestvovedeniye
# Article 'Obshchestvovedeniye' saved to CSV.
# Fetching content for article: Occupational science
# Article 'Occupational science' saved to CSV.
# Fetching content for article: Operationalization
# Article 'Operationalization' saved to CSV.
# Fetching content for article: Paedology
# Article 'Paedology' saved to CSV.
# Fetching content for article: Performance science
# Article 'Performance science' saved to CSV.
# Fetching content for article: Platform capitalism
# Article 'Platform capitalism' saved to CSV.
# Fetching content for article: Praxeology
# Article 'Praxeology' saved to CSV.
# Fetching content for article: Progress
# Article 'Progress' saved to CSV.
# Fetching content for article: Psychiatry
# Article 'Psychiatry' saved to CSV.
# Fetching content for article: Quantum social science
# Article 'Quantum social science' saved to CSV.
# Fetching content for article: Representative sequences
# Article 'Representative sequences' saved to CSV.
# Fetching content for article: Samhällsvetenskapsprogrammet
# Article 'Samhällsvetenskapsprogrammet' saved to CSV.
# Fetching content for article: Science and technology studies
# Article 'Science and technology studies' saved to CSV.
# Fetching content for article: Seriousness check
# Article 'Seriousness check' saved to CSV.
# Fetching content for article: Social neuroscience
# Article 'Social neuroscience' saved to CSV.
# Fetching content for article: Social services
# Article 'Social services' saved to CSV.
# Fetching content for article: Social simulation
# Article 'Social simulation' saved to CSV.
# Fetching content for article: Social studies
# Article 'Social studies' saved to CSV.
# Fetching content for article: Social work
# Article 'Social work' saved to CSV.
# Fetching content for article: Social work management
# Article 'Social work management' saved to CSV.
# Fetching content for article: Spatial turn
# Article 'Spatial turn' saved to CSV.
# Fetching content for article: Standard social science model
# Article 'Standard social science model' saved to CSV.
# Fetching content for article: Visual anthropology
# Article 'Visual anthropology' saved to CSV.
# Fetching content for article: Visual ethnography
# Article 'Visual ethnography' saved to CSV.
# Fetching content for article: Vyavahāramālā
# Article 'Vyavahāramālā' saved to CSV.
# Fetching content for article: War studies
# Article 'War studies' saved to CSV.
# Fetching content for article: Youth culture
# Article 'Youth culture' saved to CSV.
# Fetching content for article: Youth intervention
# Article 'Youth intervention' saved to CSV.
# Fetching content for article: Youth services
# Article 'Youth services' saved to CSV.
# Fetching content for article: Youth studies
# Article 'Youth studies' saved to CSV.
# Fetching content for article: Zemiology
# Article 'Zemiology' saved to CSV.
# Fetching content for article: Category:Social scientists
# Article 'Category:Social scientists' saved to CSV.
# Fetching content for article: Category:History of social sciences
# Article 'Category:History of social sciences' saved to CSV.
# Fetching content for article: Category:Philosophy of social science
# Article 'Category:Philosophy of social science' saved to CSV.
# Fetching content for article: Category:Social ideologies
# Article 'Category:Social ideologies' saved to CSV.
# Fetching content for article: Category:Social sciences awards
# Article 'Category:Social sciences awards' saved to CSV.
# Fetching content for article: Category:Social science fiction
# Article 'Category:Social science fiction' saved to CSV.
# Fetching content for article: Category:Social sciences literature
# Article 'Category:Social sciences literature' saved to CSV.
# Fetching content for article: Category:Social science occupations
# Article 'Category:Social science occupations' saved to CSV.
# Fetching content for article: Category:Social sciences organizations
# Article 'Category:Social sciences organizations' saved to CSV.
# Fetching content for article: Category:Social research
# Article 'Category:Social research' saved to CSV.
# Fetching content for article: Category:Social theories
# Article 'Category:Social theories' saved to CSV.
# Fetching content for article: Category:Social sciences lists
# Article 'Category:Social sciences lists' saved to CSV.
# Fetching content for article: Category:Social sciences terminology
# Article 'Category:Social sciences terminology' saved to CSV.
# Fetching content for article: Category:Anthropology
# Article 'Category:Anthropology' saved to CSV.
# Fetching content for article: Category:Archaeology
# Article 'Category:Archaeology' saved to CSV.
# Fetching content for article: Category:Behavioural sciences
# Article 'Category:Behavioural sciences' saved to CSV.
# Fetching content for article: Category:Cognitive science
# Article 'Category:Cognitive science' saved to CSV.
# Fetching content for article: Category:Communication design
# Article 'Category:Communication design' saved to CSV.
# Fetching content for article: Category:Computational social science
# Article 'Category:Computational social science' saved to CSV.
# Fetching content for article: Category:Computer-mediated communication
# Article 'Category:Computer-mediated communication' saved to CSV.
# Fetching content for article: Category:Development studies
# Article 'Category:Development studies' saved to CSV.
# Fetching content for article: Category:Social science disambiguation pages
# Article 'Category:Social science disambiguation pages' saved to CSV.
# Fetching content for article: Category:Economics
# Article 'Category:Economics' saved to CSV.
# Fetching content for article: Category:Education theory
# Article 'Category:Education theory' saved to CSV.
# Fetching content for article: Category:Environmental social science
# Article 'Category:Environmental social science' saved to CSV.
# Fetching content for article: Category:Euthenics
# Article 'Category:Euthenics' saved to CSV.
# Fetching content for article: Category:GLAM (culture and information)
# Article 'Category:GLAM (culture and information)' saved to CSV.
# Fetching content for article: Category:History
# Article 'Category:History' saved to CSV.
# Fetching content for article: Category:Human development
# Article 'Category:Human development' saved to CSV.
# Fetching content for article: Category:Human geography
# Article 'Category:Human geography' saved to CSV.
# Fetching content for article: Category:Human sciences
# Article 'Category:Human sciences' saved to CSV.
# Fetching content for article: Category:Social science indices
# Article 'Category:Social science indices' saved to CSV.
# Fetching content for article: Category:Labor studies
# Article 'Category:Labor studies' saved to CSV.
# Fetching content for article: Category:Library and information science
# Article 'Category:Library and information science' saved to CSV.
# Fetching content for article: Category:Linguistics
# Article 'Category:Linguistics' saved to CSV.
# Fetching content for article: Category:Media studies
# Article 'Category:Media studies' saved to CSV.
# Fetching content for article: Category:Military science
# Article 'Category:Military science' saved to CSV.
# Fetching content for article: Category:Modern studies
# Article 'Category:Modern studies' saved to CSV.
# Fetching content for article: Category:Network science
# Article 'Category:Network science' saved to CSV.
# Fetching content for article: Category:Peace and conflict studies
# Article 'Category:Peace and conflict studies' saved to CSV.
# Fetching content for article: Category:Political science
# Article 'Category:Political science' saved to CSV.
# Fetching content for article: Category:Psychology
# Article 'Category:Psychology' saved to CSV.
# Fetching content for article: Category:Regional science
# Article 'Category:Regional science' saved to CSV.
# Fetching content for article: Category:Security studies
# Article 'Category:Security studies' saved to CSV.
# Fetching content for article: Category:Social physics
# Article 'Category:Social physics' saved to CSV.
# Fetching content for article: Category:Social science methodology
# Article 'Category:Social science methodology' saved to CSV.
# Fetching content for article: Category:Sociology
# Article 'Category:Sociology' saved to CSV.
# Fetching content for article: Category:Thanatology
# Article 'Category:Thanatology' saved to CSV.
# Fetching content for article: Category:Urban planning
# Article 'Category:Urban planning' saved to CSV.
# Fetching content for article: Category:Social science stubs
# Article 'Category:Social science stubs' saved to CSV.
#
# Fetching articles for category: Psychology
# Fetching content for article: Psychology
# Article 'Psychology' saved to CSV.
# Fetching content for article: Outline of psychology
# Article 'Outline of psychology' saved to CSV.
# Fetching content for article: Belief congruence
# Article 'Belief congruence' saved to CSV.
# Fetching content for article: Collusion (psychology)
# Article 'Collusion (psychology)' saved to CSV.
# Fetching content for article: Counterphobic attitude
# Article 'Counterphobic attitude' saved to CSV.
# Fetching content for article: Emotion
# Article 'Emotion' saved to CSV.
# Fetching content for article: Limerence
# Article 'Limerence' saved to CSV.
# Fetching content for article: Masculine fragility
# Article 'Masculine fragility' saved to CSV.
# Fetching content for article: Motivation
# Article 'Motivation' saved to CSV.
# Fetching content for article: Musical escapism
# Article 'Musical escapism' saved to CSV.
# Fetching content for article: My Dao method
# Article 'My Dao method' saved to CSV.
# Fetching content for article: Nurture
# Article 'Nurture' saved to CSV.
# Fetching content for article: Open Path Collective
# Article 'Open Path Collective' saved to CSV.
# Fetching content for article: Passionate and companionate love
# Article 'Passionate and companionate love' saved to CSV.
# Fetching content for article: Perceptual vigilance
# Article 'Perceptual vigilance' saved to CSV.
# Fetching content for article: Personality neuroscience
# Article 'Personality neuroscience' saved to CSV.
# Fetching content for article: Psychologist
# Article 'Psychologist' saved to CSV.
# Fetching content for article: Resilience week
# Article 'Resilience week' saved to CSV.
# Fetching content for article: Social buffering
# Article 'Social buffering' saved to CSV.
# Fetching content for article: The Type Mapping System
# Article 'The Type Mapping System' saved to CSV.
# Fetching content for article: Three Principles Psychology
# Article 'Three Principles Psychology' saved to CSV.
# Fetching content for article: Vicarious mediation and vicarious functioning
# Article 'Vicarious mediation and vicarious functioning' saved to CSV.
# Fetching content for article: Portal:Psychology
# Article 'Portal:Psychology' saved to CSV.
# Fetching content for article: Category:Branches of psychology
# Article 'Category:Branches of psychology' saved to CSV.
# Fetching content for article: Category:Psychologists
# Article 'Category:Psychologists' saved to CSV.
# Fetching content for article: Category:Psychology writers
# Article 'Category:Psychology writers' saved to CSV.
# Fetching content for article: Category:Works about psychology
# Article 'Category:Works about psychology' saved to CSV.
# Fetching content for article: Category:Psychology lists
# Article 'Category:Psychology lists' saved to CSV.
# Fetching content for article: Category:Psychology awards
# Article 'Category:Psychology awards' saved to CSV.
# Fetching content for article: Category:Psychological concepts
# Article 'Category:Psychological concepts' saved to CSV.
# Fetching content for article: Category:Psychology controversies
# Article 'Category:Psychology controversies' saved to CSV.
# Fetching content for article: Category:Psychology education
# Article 'Category:Psychology education' saved to CSV.
# Fetching content for article: Category:Psychological effects
# Article 'Category:Psychological effects' saved to CSV.
# Fetching content for article: Category:Emotion
# Article 'Category:Emotion' saved to CSV.
# Fetching content for article: Category:History of psychology
# Article 'Category:History of psychology' saved to CSV.
# Fetching content for article: Category:Psychology images
# Article 'Category:Psychology images' saved to CSV.
# Fetching content for article: Category:Psychological methodology
# Article 'Category:Psychological methodology' saved to CSV.
# Fetching content for article: Category:Psychology organizations
# Article 'Category:Psychology organizations' saved to CSV.
# Fetching content for article: Category:Philosophy of psychology
# Article 'Category:Philosophy of psychology' saved to CSV.
# Fetching content for article: Category:Popular psychology
# Article 'Category:Popular psychology' saved to CSV.
# Fetching content for article: Category:Psychological schools
# Article 'Category:Psychological schools' saved to CSV.
# Fetching content for article: Category:Self-portraiture
# Article 'Category:Self-portraiture' saved to CSV.
# Fetching content for article: Category:Sexual orientation and psychology
# Article 'Category:Sexual orientation and psychology' saved to CSV.
# Fetching content for article: Category:Psychological testing
# Article 'Category:Psychological testing' saved to CSV.
# Fetching content for article: Category:Psychological theories
# Article 'Category:Psychological theories' saved to CSV.
# Fetching content for article: Category:Women and psychology
# Article 'Category:Women and psychology' saved to CSV.
# Fetching content for article: Category:Psychology stubs
# Article 'Category:Psychology stubs' saved to CSV.
# Fetching content for article: Category:Psychology templates
# Article 'Category:Psychology templates' saved to CSV.
# Fetching content for article: Category:Psychology portal
# Article 'Category:Psychology portal' saved to CSV.

# %% [markdown]
# # 1. Text Preprocessing
# - remove irrelevant section like refrence, external links

# %%
import os
import pandas as pd
import re

def clean_content(content):
    """
    Function to clean unwanted sections from the scraped Wikipedia content.
    """
    if not isinstance(content, str):
        return ""  # Return an empty string if content is not a string
    
    # Remove unwanted sections like 'See also', 'References', and 'External links'
    unwanted_patterns = [
        r"== See also ==.*",  # Remove 'See also' sections
        r"== References ==.*",  # Remove 'References' sections
        r"== External links ==.*",  # Remove 'External links' sections
        r"Media related to .* at Wikimedia Commons",  # Remove media-related phrases
        r"== Additional images ==.*", # Remove additional images
        r"== Further reading ==.*",  # Remove 'Further reading' sections
        r"== Notes ==.*",  # Remove 'Notes' sections
        r"== Bibliography ==.*",  # Remove 'Bibliography' sections
        r"== Citations ==.*"  # Remove 'Citations' sections
    ]

    for pattern in unwanted_patterns:
        content = re.sub(pattern, "", content, flags=re.DOTALL)
    
    # Additional cleaning: Remove excessive whitespace, line breaks, and non-alphanumeric characters
    content = re.sub(r'\s+', ' ', content)  # Replace multiple whitespaces with a single space
    content = re.sub(r'[^\w\s]', '', content)  # Remove non-alphanumeric characters (except spaces)
    
    # Return cleaned content
    return content.strip()

def clean_csv(input_file, output_file):
    """
    Read a CSV file, clean its content, and save the cleaned data to a new CSV file.
    """
    # Read the CSV file
    df = pd.read_csv(input_file)
    
    # Check if the 'Content' column exists in the DataFrame
    if 'Content' not in df.columns:
        print(f"No 'Content' column found in {input_file}. Skipping this file.")
        return
    
    # Clean the 'Content' column
    df['Content'] = df['Content'].apply(clean_content)
    
    # Optionally, remove rows where content is empty after cleaning
    df = df[df['Content'].str.strip() != '']
    
    # Save the cleaned data to a new CSV
    df.to_csv(output_file, index=False)
    print(f"Cleaned CSV saved to: {output_file}")

def clean_all_csvs(input_folder, output_folder):
    """
    Clean all CSV files in the input folder and save cleaned files to the output folder.
    """
    # Check if output folder exists, if not create it
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Iterate over all CSV files in the input folder
    for file_name in os.listdir(input_folder):
        if file_name.endswith('.csv'):
            input_file = os.path.join(input_folder, file_name)
            output_file = os.path.join(output_folder, file_name)
            
            # Clean the CSV file
            clean_csv(input_file, output_file)

# Define the input and output folders
input_folder = 'data/original_data'
output_folder = 'data/clean_data'

# Clean all CSV files in the original_data folder
clean_all_csvs(input_folder, output_folder)
# Out:
# Cleaned CSV saved to: data/clean_data\Abdomen.csv
# Cleaned CSV saved to: data/clean_data\Achilles tendon.csv
# Cleaned CSV saved to: data/clean_data\Adductor hiatus.csv
# Cleaned CSV saved to: data/clean_data\Administrative history.csv
# Cleaned CSV saved to: data/clean_data\Allergist.csv
# Cleaned CSV saved to: data/clean_data\Alveolus.csv
# Cleaned CSV saved to: data/clean_data\Amniotic sac.csv
# Cleaned CSV saved to: data/clean_data\Anatomical terminology.csv
# Cleaned CSV saved to: data/clean_data\Anatomical terms of bone.csv
# Cleaned CSV saved to: data/clean_data\Anatomical terms of muscle.csv
# Cleaned CSV saved to: data/clean_data\Anatomical terms of neuroanatomy.csv
# Cleaned CSV saved to: data/clean_data\Anatomy Charts of the Arabs.csv
# Cleaned CSV saved to: data/clean_data\Anatomy of human.csv
# Cleaned CSV saved to: data/clean_data\Animal studies.csv
# Cleaned CSV saved to: data/clean_data\Anorectal canal.csv
# Cleaned CSV saved to: data/clean_data\Anthropocene Working Group.csv
# Cleaned CSV saved to: data/clean_data\Anthropomaximology.csv
# Cleaned CSV saved to: data/clean_data\Anthropometry.csv
# Cleaned CSV saved to: data/clean_data\Anti-aging medicine.csv
# Cleaned CSV saved to: data/clean_data\Anti-asthmatic agent.csv
# Cleaned CSV saved to: data/clean_data\Aortopulmonary space.csv
# Cleaned CSV saved to: data/clean_data\Ape hand deformity.csv
# Cleaned CSV saved to: data/clean_data\Apollo's belt.csv
# Cleaned CSV saved to: data/clean_data\Arthrology.csv
# Cleaned CSV saved to: data/clean_data\Ascribed characteristics.csv
# Cleaned CSV saved to: data/clean_data\Axial skeleton.csv
# Cleaned CSV saved to: data/clean_data\Beclard Triangle.csv
# Cleaned CSV saved to: data/clean_data\Belief congruence.csv
# Cleaned CSV saved to: data/clean_data\Bioculture.csv
# Cleaned CSV saved to: data/clean_data\Biomedical sciences.csv
# Cleaned CSV saved to: data/clean_data\Body Worlds.csv
# Cleaned CSV saved to: data/clean_data\Brain connectivity estimators.csv
# Cleaned CSV saved to: data/clean_data\Breastmilk medicine.csv
# Cleaned CSV saved to: data/clean_data\Bregma.csv
# Cleaned CSV saved to: data/clean_data\Cancer exodus hypothesis.csv
# Cleaned CSV saved to: data/clean_data\Category_Absent body parts.csv
# Cleaned CSV saved to: data/clean_data\Category_Academic health science centres.csv
# Cleaned CSV saved to: data/clean_data\Category_Addiction medicine.csv
# Cleaned CSV saved to: data/clean_data\Category_Alternative medicine.csv
# Cleaned CSV saved to: data/clean_data\Category_Amniotic sac.csv
# Cleaned CSV saved to: data/clean_data\Category_Anatomical variations.csv
# Cleaned CSV saved to: data/clean_data\Category_Anatomy named for one who described it.csv
# Cleaned CSV saved to: data/clean_data\Category_Andrology.csv
# Cleaned CSV saved to: data/clean_data\Category_Anesthesiology.csv
# Cleaned CSV saved to: data/clean_data\Category_Angiology.csv
# Cleaned CSV saved to: data/clean_data\Category_Anthropology.csv
# Cleaned CSV saved to: data/clean_data\Category_Anthropometry.csv
# Cleaned CSV saved to: data/clean_data\Category_Archaeology.csv
# Cleaned CSV saved to: data/clean_data\Category_Arthrology.csv
# Cleaned CSV saved to: data/clean_data\Category_Audiology.csv
# Cleaned CSV saved to: data/clean_data\Category_Auxology.csv
# Cleaned CSV saved to: data/clean_data\Category_Aviation medicine.csv
# Cleaned CSV saved to: data/clean_data\Category_Back anatomy.csv
# Cleaned CSV saved to: data/clean_data\Category_Behavioural sciences.csv
# Cleaned CSV saved to: data/clean_data\Category_Biological engineering.csv
# Cleaned CSV saved to: data/clean_data\Category_Biomedicine.csv
# Cleaned CSV saved to: data/clean_data\Category_Biotechnology.csv
# Cleaned CSV saved to: data/clean_data\Category_Branches of medical specialties.csv
# Cleaned CSV saved to: data/clean_data\Category_Branches of psychology.csv
# Cleaned CSV saved to: data/clean_data\Category_Cardiology.csv
# Cleaned CSV saved to: data/clean_data\Category_Cause (medicine).csv
# Cleaned CSV saved to: data/clean_data\Category_Chemicals in medicine.csv
# Cleaned CSV saved to: data/clean_data\Category_Circulatory system.csv
# Cleaned CSV saved to: data/clean_data\Category_Clinical medicine.csv
# Cleaned CSV saved to: data/clean_data\Category_Clinical pharmacology.csv
# Cleaned CSV saved to: data/clean_data\Category_Cognitive science.csv
# Cleaned CSV saved to: data/clean_data\Category_Communication design.csv
# Cleaned CSV saved to: data/clean_data\Category_Computational social science.csv
# Cleaned CSV saved to: data/clean_data\Category_Computer-mediated communication.csv
# Cleaned CSV saved to: data/clean_data\Category_Dentistry.csv
# Cleaned CSV saved to: data/clean_data\Category_Dermatology.csv
# Cleaned CSV saved to: data/clean_data\Category_Development studies.csv
# Cleaned CSV saved to: data/clean_data\Category_Earth sciences.csv
# Cleaned CSV saved to: data/clean_data\Category_Economics.csv
# Cleaned CSV saved to: data/clean_data\Category_Education theory.csv
# Cleaned CSV saved to: data/clean_data\Category_Emergency medicine.csv
# Cleaned CSV saved to: data/clean_data\Category_Emotion.csv
# Cleaned CSV saved to: data/clean_data\Category_Endocrinology.csv
# Cleaned CSV saved to: data/clean_data\Category_Environmental social science.csv
# Cleaned CSV saved to: data/clean_data\Category_Epidemiology.csv
# Cleaned CSV saved to: data/clean_data\Category_Euthenics.csv
# Cleaned CSV saved to: data/clean_data\Category_Facial features.csv
# Cleaned CSV saved to: data/clean_data\Category_Gastroenterology.csv
# Cleaned CSV saved to: data/clean_data\Category_General practice.csv
# Cleaned CSV saved to: data/clean_data\Category_Geriatrics.csv
# Cleaned CSV saved to: data/clean_data\Category_GLAM (culture and information).csv
# Cleaned CSV saved to: data/clean_data\Category_Glands.csv
# Cleaned CSV saved to: data/clean_data\Category_Gynaecology.csv
# Cleaned CSV saved to: data/clean_data\Category_Health physicists.csv
# Cleaned CSV saved to: data/clean_data\Category_Health sciences by country.csv
# Cleaned CSV saved to: data/clean_data\Category_Health sciences organizations.csv
# Cleaned CSV saved to: data/clean_data\Category_Health sciences publications.csv
# Cleaned CSV saved to: data/clean_data\Category_Health sciences schools.csv
# Cleaned CSV saved to: data/clean_data\Category_Health-related conspiracy theories.csv
# Cleaned CSV saved to: data/clean_data\Category_Hematology.csv
# Cleaned CSV saved to: data/clean_data\Category_Hepatology.csv
# Cleaned CSV saved to: data/clean_data\Category_History of medical and surgical specialties.csv
# Cleaned CSV saved to: data/clean_data\Category_History of medicine.csv
# Cleaned CSV saved to: data/clean_data\Category_History of psychology.csv
# Cleaned CSV saved to: data/clean_data\Category_History of social sciences.csv
# Cleaned CSV saved to: data/clean_data\Category_History.csv
# Cleaned CSV saved to: data/clean_data\Category_Hospital medicine.csv
# Cleaned CSV saved to: data/clean_data\Category_Human anatomy by organ.csv
# Cleaned CSV saved to: data/clean_data\Category_Human anatomy by system.csv
# Cleaned CSV saved to: data/clean_data\Category_Human anatomy museums.csv
# Cleaned CSV saved to: data/clean_data\Category_Human development.csv
# Cleaned CSV saved to: data/clean_data\Category_Human geography.csv
# Cleaned CSV saved to: data/clean_data\Category_Human head and neck.csv
# Cleaned CSV saved to: data/clean_data\Category_Human sciences.csv
# Cleaned CSV saved to: data/clean_data\Category_Human size.csv
# Cleaned CSV saved to: data/clean_data\Category_Human skin.csv
# Cleaned CSV saved to: data/clean_data\Category_Human surface anatomy.csv
# Cleaned CSV saved to: data/clean_data\Category_ILAE Wikipedia Project.csv
# Cleaned CSV saved to: data/clean_data\Category_Immunology.csv
# Cleaned CSV saved to: data/clean_data\Category_Intensive care medicine.csv
# Cleaned CSV saved to: data/clean_data\Category_Interdisciplinary subfields of medicine.csv
# Cleaned CSV saved to: data/clean_data\Category_Internal medicine.csv
# Cleaned CSV saved to: data/clean_data\Category_Intersex and medicine.csv
# Cleaned CSV saved to: data/clean_data\Category_Labor studies.csv
# Cleaned CSV saved to: data/clean_data\Category_Library and information science.csv
# Cleaned CSV saved to: data/clean_data\Category_Life sciences.csv
# Cleaned CSV saved to: data/clean_data\Category_Limbs (anatomy).csv
# Cleaned CSV saved to: data/clean_data\Category_Linguistics.csv
# Cleaned CSV saved to: data/clean_data\Category_Lists of human anatomical features.csv
# Cleaned CSV saved to: data/clean_data\Category_Media studies.csv
# Cleaned CSV saved to: data/clean_data\Category_Medical activism.csv
# Cleaned CSV saved to: data/clean_data\Category_Medical and health organizations by subject.csv
# Cleaned CSV saved to: data/clean_data\Category_Medical and health organizations.csv
# Cleaned CSV saved to: data/clean_data\Category_Medical aspects of death.csv
# Cleaned CSV saved to: data/clean_data\Category_Medical associations.csv
# Cleaned CSV saved to: data/clean_data\Category_Medical diplomacy.csv
# Cleaned CSV saved to: data/clean_data\Category_Medical doctors by specialty.csv
# Cleaned CSV saved to: data/clean_data\Category_Medical education by branch.csv
# Cleaned CSV saved to: data/clean_data\Category_Medical education.csv
# Cleaned CSV saved to: data/clean_data\Category_Medical genetics.csv
# Cleaned CSV saved to: data/clean_data\Category_Medical humanities.csv
# Cleaned CSV saved to: data/clean_data\Category_Medical lists.csv
# Cleaned CSV saved to: data/clean_data\Category_Medical literature by subject.csv
# Cleaned CSV saved to: data/clean_data\Category_Medical microbiology.csv
# Cleaned CSV saved to: data/clean_data\Category_Medical phenomena.csv
# Cleaned CSV saved to: data/clean_data\Category_Medical prevention.csv
# Cleaned CSV saved to: data/clean_data\Category_Medical research.csv
# Cleaned CSV saved to: data/clean_data\Category_Medical statistics.csv
# Cleaned CSV saved to: data/clean_data\Category_Medical symbols.csv
# Cleaned CSV saved to: data/clean_data\Category_Medical technology.csv
# Cleaned CSV saved to: data/clean_data\Category_Medical terminology.csv
# Cleaned CSV saved to: data/clean_data\Category_Medical volunteerism.csv
# Cleaned CSV saved to: data/clean_data\Category_Medicine awards.csv
# Cleaned CSV saved to: data/clean_data\Category_Medicine by century.csv
# Cleaned CSV saved to: data/clean_data\Category_Medicine by city.csv
# Cleaned CSV saved to: data/clean_data\Category_Medicine by country subdivision.csv
# Cleaned CSV saved to: data/clean_data\Category_Medicine by country.csv
# Cleaned CSV saved to: data/clean_data\Category_Medicine by decade.csv
# Cleaned CSV saved to: data/clean_data\Category_Medicine by dependent territory.csv
# Cleaned CSV saved to: data/clean_data\Category_Medicine by year.csv
# Cleaned CSV saved to: data/clean_data\Category_Medicine in society.csv
# Cleaned CSV saved to: data/clean_data\Category_Medicine stubs.csv
# Cleaned CSV saved to: data/clean_data\Category_Medicine.csv
# Cleaned CSV saved to: data/clean_data\Category_Men's health.csv
# Cleaned CSV saved to: data/clean_data\Category_Midwifery.csv
# Cleaned CSV saved to: data/clean_data\Category_Military medicine.csv
# Cleaned CSV saved to: data/clean_data\Category_Military science.csv
# Cleaned CSV saved to: data/clean_data\Category_Modern studies.csv
# Cleaned CSV saved to: data/clean_data\Category_Natural history.csv
# Cleaned CSV saved to: data/clean_data\Category_Natural science stubs.csv
# Cleaned CSV saved to: data/clean_data\Category_Natural scientists.csv
# Cleaned CSV saved to: data/clean_data\Category_Nephrology.csv
# Cleaned CSV saved to: data/clean_data\Category_Network science.csv
# Cleaned CSV saved to: data/clean_data\Category_Neuroanatomy.csv
# Cleaned CSV saved to: data/clean_data\Category_Neurology.csv
# Cleaned CSV saved to: data/clean_data\Category_Nuclear medicine.csv
# Cleaned CSV saved to: data/clean_data\Category_Nursing specialties.csv
# Cleaned CSV saved to: data/clean_data\Category_Nursing.csv
# Cleaned CSV saved to: data/clean_data\Category_Obstetrics.csv
# Cleaned CSV saved to: data/clean_data\Category_Occupational medicine.csv
# Cleaned CSV saved to: data/clean_data\Category_Oncology.csv
# Cleaned CSV saved to: data/clean_data\Category_Ophthalmology.csv
# Cleaned CSV saved to: data/clean_data\Category_Orthopedics.csv
# Cleaned CSV saved to: data/clean_data\Category_Otorhinolaryngology.csv
# Cleaned CSV saved to: data/clean_data\Category_Parasitology.csv
# Cleaned CSV saved to: data/clean_data\Category_Pathology.csv
# Cleaned CSV saved to: data/clean_data\Category_Peace and conflict studies.csv
# Cleaned CSV saved to: data/clean_data\Category_Pediatrics.csv
# Cleaned CSV saved to: data/clean_data\Category_Pharmaceutical sciences.csv
# Cleaned CSV saved to: data/clean_data\Category_Pharmacy.csv
# Cleaned CSV saved to: data/clean_data\Category_Philosophy of psychology.csv
# Cleaned CSV saved to: data/clean_data\Category_Philosophy of social science.csv
# Cleaned CSV saved to: data/clean_data\Category_Physical sciences.csv
# Cleaned CSV saved to: data/clean_data\Category_Podiatry.csv
# Cleaned CSV saved to: data/clean_data\Category_Political science.csv
# Cleaned CSV saved to: data/clean_data\Category_Popular psychology.csv
# Cleaned CSV saved to: data/clean_data\Category_Practice of medicine.csv
# Cleaned CSV saved to: data/clean_data\Category_Prescription of drugs.csv
# Cleaned CSV saved to: data/clean_data\Category_Preventive medicine.csv
# Cleaned CSV saved to: data/clean_data\Category_Prison healthcare.csv
# Cleaned CSV saved to: data/clean_data\Category_Psychiatry.csv
# Cleaned CSV saved to: data/clean_data\Category_Psychological concepts.csv
# Cleaned CSV saved to: data/clean_data\Category_Psychological effects.csv
# Cleaned CSV saved to: data/clean_data\Category_Psychological methodology.csv
# Cleaned CSV saved to: data/clean_data\Category_Psychological schools.csv
# Cleaned CSV saved to: data/clean_data\Category_Psychological testing.csv
# Cleaned CSV saved to: data/clean_data\Category_Psychological theories.csv
# Cleaned CSV saved to: data/clean_data\Category_Psychologists.csv
# Cleaned CSV saved to: data/clean_data\Category_Psychology awards.csv
# Cleaned CSV saved to: data/clean_data\Category_Psychology controversies.csv
# Cleaned CSV saved to: data/clean_data\Category_Psychology education.csv
# Cleaned CSV saved to: data/clean_data\Category_Psychology images.csv
# Cleaned CSV saved to: data/clean_data\Category_Psychology lists.csv
# Cleaned CSV saved to: data/clean_data\Category_Psychology organizations.csv
# Cleaned CSV saved to: data/clean_data\Category_Psychology portal.csv
# Cleaned CSV saved to: data/clean_data\Category_Psychology stubs.csv
# Cleaned CSV saved to: data/clean_data\Category_Psychology templates.csv
# Cleaned CSV saved to: data/clean_data\Category_Psychology writers.csv
# Cleaned CSV saved to: data/clean_data\Category_Psychology.csv
# Cleaned CSV saved to: data/clean_data\Category_Public health.csv
# Cleaned CSV saved to: data/clean_data\Category_Pulmonology.csv
# Cleaned CSV saved to: data/clean_data\Category_Radiology.csv
# Cleaned CSV saved to: data/clean_data\Category_Railway surgery.csv
# Cleaned CSV saved to: data/clean_data\Category_Regional science.csv
# Cleaned CSV saved to: data/clean_data\Category_Rehabilitation medicine.csv
# Cleaned CSV saved to: data/clean_data\Category_Religion and medicine.csv
# Cleaned CSV saved to: data/clean_data\Category_Rheumatology.csv
# Cleaned CSV saved to: data/clean_data\Category_Security studies.csv
# Cleaned CSV saved to: data/clean_data\Category_Self-portraiture.csv
# Cleaned CSV saved to: data/clean_data\Category_Seventh-day Adventists in health science.csv
# Cleaned CSV saved to: data/clean_data\Category_Sexual health.csv
# Cleaned CSV saved to: data/clean_data\Category_Sexual orientation and psychology.csv
# Cleaned CSV saved to: data/clean_data\Category_Sleep medicine.csv
# Cleaned CSV saved to: data/clean_data\Category_Social ideologies.csv
# Cleaned CSV saved to: data/clean_data\Category_Social physics.csv
# Cleaned CSV saved to: data/clean_data\Category_Social research.csv
# Cleaned CSV saved to: data/clean_data\Category_Social science disambiguation pages.csv
# Cleaned CSV saved to: data/clean_data\Category_Social science fiction.csv
# Cleaned CSV saved to: data/clean_data\Category_Social science indices.csv
# Cleaned CSV saved to: data/clean_data\Category_Social science methodology.csv
# Cleaned CSV saved to: data/clean_data\Category_Social science occupations.csv
# Cleaned CSV saved to: data/clean_data\Category_Social science stubs.csv
# Cleaned CSV saved to: data/clean_data\Category_Social sciences awards.csv
# Cleaned CSV saved to: data/clean_data\Category_Social sciences lists.csv
# Cleaned CSV saved to: data/clean_data\Category_Social sciences literature.csv
# Cleaned CSV saved to: data/clean_data\Category_Social sciences organizations.csv
# Cleaned CSV saved to: data/clean_data\Category_Social sciences terminology.csv
# Cleaned CSV saved to: data/clean_data\Category_Social scientists.csv
# Cleaned CSV saved to: data/clean_data\Category_Social theories.csv
# Cleaned CSV saved to: data/clean_data\Category_Social work.csv
# Cleaned CSV saved to: data/clean_data\Category_Sociology.csv
# Cleaned CSV saved to: data/clean_data\Category_Space medicine.csv
# Cleaned CSV saved to: data/clean_data\Category_Sports medicine.csv
# Cleaned CSV saved to: data/clean_data\Category_Stomatologists.csv
# Cleaned CSV saved to: data/clean_data\Category_Supernumerary body parts.csv
# Cleaned CSV saved to: data/clean_data\Category_Surgery.csv
# Cleaned CSV saved to: data/clean_data\Category_Thanatology.csv
# Cleaned CSV saved to: data/clean_data\Category_Theory of medicine.csv
# Cleaned CSV saved to: data/clean_data\Category_Thermal medicine.csv
# Cleaned CSV saved to: data/clean_data\Category_Toxicology.csv
# Cleaned CSV saved to: data/clean_data\Category_Translational medicine.csv
# Cleaned CSV saved to: data/clean_data\Category_Transplantation medicine.csv
# Cleaned CSV saved to: data/clean_data\Category_Tropical medicine.csv
# Cleaned CSV saved to: data/clean_data\Category_Urban planning.csv
# Cleaned CSV saved to: data/clean_data\Category_Urinary system.csv
# Cleaned CSV saved to: data/clean_data\Category_Urology.csv
# Cleaned CSV saved to: data/clean_data\Category_Veterinary medicine.csv
# Cleaned CSV saved to: data/clean_data\Category_Women and psychology.csv
# Cleaned CSV saved to: data/clean_data\Category_Women in medicine.csv
# Cleaned CSV saved to: data/clean_data\Category_Women's health.csv
# Cleaned CSV saved to: data/clean_data\Category_Works about medicine.csv
# Cleaned CSV saved to: data/clean_data\Category_Works about psychology.csv
# Cleaned CSV saved to: data/clean_data\Cavoatrial junction.csv
# Cleaned CSV saved to: data/clean_data\Center for Anatomy of the Charité.csv
# Cleaned CSV saved to: data/clean_data\Cervical artery dissection.csv
# Cleaned CSV saved to: data/clean_data\Cervical rib.csv
# Cleaned CSV saved to: data/clean_data\Change and continuity.csv
# Cleaned CSV saved to: data/clean_data\Civil surgeon.csv
# Cleaned CSV saved to: data/clean_data\Clinical handover.csv
# Cleaned CSV saved to: data/clean_data\Clinical physiology.csv
# Cleaned CSV saved to: data/clean_data\Coccygeal glomus.csv
# Cleaned CSV saved to: data/clean_data\Collective mental state.csv
# Cleaned CSV saved to: data/clean_data\Collusion (psychology).csv
# Cleaned CSV saved to: data/clean_data\Compensatory growth (organ).csv
# Cleaned CSV saved to: data/clean_data\Composition of the human body.csv
# Cleaned CSV saved to: data/clean_data\Computational social science.csv
# Cleaned CSV saved to: data/clean_data\Conflict and Catastrophe Medicine.csv
# Cleaned CSV saved to: data/clean_data\Confocal endoscopy.csv
# Cleaned CSV saved to: data/clean_data\Corona of glans penis.csv
# Cleaned CSV saved to: data/clean_data\Counterphobic attitude.csv
# Cleaned CSV saved to: data/clean_data\Criminology.csv
# Cleaned CSV saved to: data/clean_data\Cultural studies.csv
# Cleaned CSV saved to: data/clean_data\Darwin's tubercle.csv
# Cleaned CSV saved to: data/clean_data\Data Colada.csv
# Cleaned CSV saved to: data/clean_data\Dental anatomy.csv
# Cleaned CSV saved to: data/clean_data\Dermatocranium.csv
# Cleaned CSV saved to: data/clean_data\Desjardins' point.csv
# Cleaned CSV saved to: data/clean_data\Diabetes self-management.csv
# Cleaned CSV saved to: data/clean_data\Distributive justice.csv
# Cleaned CSV saved to: data/clean_data\Diving Medical Examiner.csv
# Cleaned CSV saved to: data/clean_data\Diving Medical Practitioner.csv
# Cleaned CSV saved to: data/clean_data\Diving medicine.csv
# Cleaned CSV saved to: data/clean_data\Doctor of Social Science.csv
# Cleaned CSV saved to: data/clean_data\Dorsal body cavity.csv
# Cleaned CSV saved to: data/clean_data\Dorsal pancreatic agenesis.csv
# Cleaned CSV saved to: data/clean_data\Drone-Enhanced Emergency Medical Services.csv
# Cleaned CSV saved to: data/clean_data\Eardrum.csv
# Cleaned CSV saved to: data/clean_data\Efficient Voter Rule.csv
# Cleaned CSV saved to: data/clean_data\Emotion.csv
# Cleaned CSV saved to: data/clean_data\Enchantment (social sciences).csv
# Cleaned CSV saved to: data/clean_data\Endocranium.csv
# Cleaned CSV saved to: data/clean_data\Environmental medicine.csv
# Cleaned CSV saved to: data/clean_data\Epidemiology.csv
# Cleaned CSV saved to: data/clean_data\Episternal ossicles.csv
# Cleaned CSV saved to: data/clean_data\Estrogenic fat.csv
# Cleaned CSV saved to: data/clean_data\Eustachian tube.csv
# Cleaned CSV saved to: data/clean_data\Evelyn tables.csv
# Cleaned CSV saved to: data/clean_data\Exercise medicine.csv
# Cleaned CSV saved to: data/clean_data\Extensor retinaculum of the hand.csv
# Cleaned CSV saved to: data/clean_data\Eyelid.csv
# Cleaned CSV saved to: data/clean_data\Fascial Net Plastination Project.csv
# Cleaned CSV saved to: data/clean_data\Fascial spaces of the head and neck.csv
# Cleaned CSV saved to: data/clean_data\Fingerprint.csv
# Cleaned CSV saved to: data/clean_data\Fontanelle.csv
# Cleaned CSV saved to: data/clean_data\Foramen singulare.csv
# Cleaned CSV saved to: data/clean_data\Force-field analysis.csv
# Cleaned CSV saved to: data/clean_data\Foreskin.csv
# Cleaned CSV saved to: data/clean_data\Fossa navicularis magna.csv
# Cleaned CSV saved to: data/clean_data\Geography.csv
# Cleaned CSV saved to: data/clean_data\Glabella.csv
# Cleaned CSV saved to: data/clean_data\Global health.csv
# Cleaned CSV saved to: data/clean_data\Groin.csv
# Cleaned CSV saved to: data/clean_data\Growing teeth.csv
# Cleaned CSV saved to: data/clean_data\Gulbenkian commission.csv
# Cleaned CSV saved to: data/clean_data\Health care.csv
# Cleaned CSV saved to: data/clean_data\Health crisis.csv
# Cleaned CSV saved to: data/clean_data\Health equity.csv
# Cleaned CSV saved to: data/clean_data\Health policy.csv
# Cleaned CSV saved to: data/clean_data\Health Sciences Descriptors.csv
# Cleaned CSV saved to: data/clean_data\Health survival paradox.csv
# Cleaned CSV saved to: data/clean_data\Health system.csv
# Cleaned CSV saved to: data/clean_data\Heortology.csv
# Cleaned CSV saved to: data/clean_data\Heterocrine gland.csv
# Cleaned CSV saved to: data/clean_data\Human back.csv
# Cleaned CSV saved to: data/clean_data\Human body.csv
# Cleaned CSV saved to: data/clean_data\Human fat.csv
# Cleaned CSV saved to: data/clean_data\Human mouth.csv
# Cleaned CSV saved to: data/clean_data\Human nose.csv
# Cleaned CSV saved to: data/clean_data\Human penis.csv
# Cleaned CSV saved to: data/clean_data\Human reproductive system.csv
# Cleaned CSV saved to: data/clean_data\Human skeleton.csv
# Cleaned CSV saved to: data/clean_data\Human tooth.csv
# Cleaned CSV saved to: data/clean_data\Human vestigiality.csv
# Cleaned CSV saved to: data/clean_data\Humanities, arts, and social sciences.csv
# Cleaned CSV saved to: data/clean_data\Iliac crest.csv
# Cleaned CSV saved to: data/clean_data\Imperial College Faculty of Natural Sciences.csv
# Cleaned CSV saved to: data/clean_data\Inferior frontal junction.csv
# Cleaned CSV saved to: data/clean_data\Institute of Human Anatomy.csv
# Cleaned CSV saved to: data/clean_data\Interdental plate.csv
# Cleaned CSV saved to: data/clean_data\International order.csv
# Cleaned CSV saved to: data/clean_data\Interoception.csv
# Cleaned CSV saved to: data/clean_data\Intrascleral plexus.csv
# Cleaned CSV saved to: data/clean_data\Isotropic bands.csv
# Cleaned CSV saved to: data/clean_data\Jurisprudence.csv
# Cleaned CSV saved to: data/clean_data\Kiesselbach's plexus.csv
# Cleaned CSV saved to: data/clean_data\Kinanthropometry.csv
# Cleaned CSV saved to: data/clean_data\Koch's triangle.csv
# Cleaned CSV saved to: data/clean_data\LAMA2 related congenital muscular dystrophy.csv
# Cleaned CSV saved to: data/clean_data\Lap.csv
# Cleaned CSV saved to: data/clean_data\Lateral palpebral raphe.csv
# Cleaned CSV saved to: data/clean_data\Limerence.csv
# Cleaned CSV saved to: data/clean_data\Lip.csv
# Cleaned CSV saved to: data/clean_data\List of anatomy mnemonics.csv
# Cleaned CSV saved to: data/clean_data\List of forms of alternative medicine.csv
# Cleaned CSV saved to: data/clean_data\List of medical specialty colleges in the United States.csv
# Cleaned CSV saved to: data/clean_data\Little finger.csv
# Cleaned CSV saved to: data/clean_data\LY-2365109.csv
# Cleaned CSV saved to: data/clean_data\Macro social work.csv
# Cleaned CSV saved to: data/clean_data\Marginal sinus.csv
# Cleaned CSV saved to: data/clean_data\Marionette lines.csv
# Cleaned CSV saved to: data/clean_data\Masculine fragility.csv
# Cleaned CSV saved to: data/clean_data\Mass gathering medicine.csv
# Cleaned CSV saved to: data/clean_data\Medical entomology.csv
# Cleaned CSV saved to: data/clean_data\Medical specialty.csv
# Cleaned CSV saved to: data/clean_data\Medical statistics.csv
# Cleaned CSV saved to: data/clean_data\Medicine.csv
# Cleaned CSV saved to: data/clean_data\Mentum.csv
# Cleaned CSV saved to: data/clean_data\Methodological nationalism.csv
# Cleaned CSV saved to: data/clean_data\Middle ear.csv
# Cleaned CSV saved to: data/clean_data\Mobilities.csv
# Cleaned CSV saved to: data/clean_data\Modern Studies.csv
# Cleaned CSV saved to: data/clean_data\Motivation.csv
# Cleaned CSV saved to: data/clean_data\Musical escapism.csv
# Cleaned CSV saved to: data/clean_data\My Dao method.csv
# Cleaned CSV saved to: data/clean_data\Natural science.csv
# Cleaned CSV saved to: data/clean_data\Natural Sciences Collections Association.csv
# Cleaned CSV saved to: data/clean_data\Nature (journal).csv
# Cleaned CSV saved to: data/clean_data\Neanderthal anatomy.csv
# Cleaned CSV saved to: data/clean_data\Neurocranium.csv
# Cleaned CSV saved to: data/clean_data\Neuroepigenetics.csv
# Cleaned CSV saved to: data/clean_data\Neurosurgical anesthesia.csv
# Cleaned CSV saved to: data/clean_data\Normativity.csv
# Cleaned CSV saved to: data/clean_data\Nudity.csv
# Cleaned CSV saved to: data/clean_data\Nurture.csv
# Cleaned CSV saved to: data/clean_data\Nutritional psychiatry.csv
# Cleaned CSV saved to: data/clean_data\Obshchestvovedeniye.csv
# Cleaned CSV saved to: data/clean_data\Occupational medicine.csv
# Cleaned CSV saved to: data/clean_data\Occupational science.csv
# Cleaned CSV saved to: data/clean_data\Oncology.csv
# Cleaned CSV saved to: data/clean_data\Open Path Collective.csv
# Cleaned CSV saved to: data/clean_data\Operationalization.csv
# Cleaned CSV saved to: data/clean_data\Oral and maxillofacial surgery.csv
# Cleaned CSV saved to: data/clean_data\Otorhinolaryngology.csv
# Cleaned CSV saved to: data/clean_data\Outline of health sciences.csv
# Cleaned CSV saved to: data/clean_data\Outline of human anatomy.csv
# Cleaned CSV saved to: data/clean_data\Outline of medicine.csv
# Cleaned CSV saved to: data/clean_data\Outline of natural science.csv
# Cleaned CSV saved to: data/clean_data\Outline of psychology.csv
# Cleaned CSV saved to: data/clean_data\Outline of social science.csv
# Cleaned CSV saved to: data/clean_data\Outline of the human nervous system.csv
# Cleaned CSV saved to: data/clean_data\Paedology.csv
# Cleaned CSV saved to: data/clean_data\Palmar aponeurosis.csv
# Cleaned CSV saved to: data/clean_data\Parasitology.csv
# Cleaned CSV saved to: data/clean_data\Passionate and companionate love.csv
# Cleaned CSV saved to: data/clean_data\Pectoral muscles.csv
# Cleaned CSV saved to: data/clean_data\Pediatric endocrinology.csv
# Cleaned CSV saved to: data/clean_data\Pelvic tilt.csv
# Cleaned CSV saved to: data/clean_data\Perceptual vigilance.csv
# Cleaned CSV saved to: data/clean_data\Performance science.csv
# Cleaned CSV saved to: data/clean_data\Personality neuroscience.csv
# Cleaned CSV saved to: data/clean_data\Petrous portion.csv
# Cleaned CSV saved to: data/clean_data\Phoniatrics.csv
# Cleaned CSV saved to: data/clean_data\Plastic surgery.csv
# Cleaned CSV saved to: data/clean_data\Platform capitalism.csv
# Cleaned CSV saved to: data/clean_data\Poison exon.csv
# Cleaned CSV saved to: data/clean_data\Population health.csv
# Cleaned CSV saved to: data/clean_data\Portal_Medicine.csv
# Cleaned CSV saved to: data/clean_data\Portal_Psychology.csv
# Cleaned CSV saved to: data/clean_data\Positive health.csv
# Cleaned CSV saved to: data/clean_data\Praxeology.csv
# Cleaned CSV saved to: data/clean_data\Prodromus.csv
# Cleaned CSV saved to: data/clean_data\Progress.csv
# Cleaned CSV saved to: data/clean_data\Psychiatry.csv
# Cleaned CSV saved to: data/clean_data\Psychologist.csv
# Cleaned CSV saved to: data/clean_data\Psychology.csv
# Cleaned CSV saved to: data/clean_data\Psychosomatic medicine.csv
# Cleaned CSV saved to: data/clean_data\Ptosis (chin).csv
# Cleaned CSV saved to: data/clean_data\Public health.csv
# Cleaned CSV saved to: data/clean_data\Publicly funded health care.csv
# Cleaned CSV saved to: data/clean_data\Quantum social science.csv
# Cleaned CSV saved to: data/clean_data\Radiographic anatomy.csv
# Cleaned CSV saved to: data/clean_data\Railway surgery.csv
# Cleaned CSV saved to: data/clean_data\Rangeland management.csv
# Cleaned CSV saved to: data/clean_data\Representative sequences.csv
# Cleaned CSV saved to: data/clean_data\Resilience week.csv
# Cleaned CSV saved to: data/clean_data\Rhombus of Michaelis.csv
# Cleaned CSV saved to: data/clean_data\Right to health.csv
# Cleaned CSV saved to: data/clean_data\RNU4-2 syndrome.csv
# Cleaned CSV saved to: data/clean_data\Rural health.csv
# Cleaned CSV saved to: data/clean_data\Samhällsvetenskapsprogrammet.csv
# Cleaned CSV saved to: data/clean_data\Scalene muscles.csv
# Cleaned CSV saved to: data/clean_data\Science and technology studies.csv
# Cleaned CSV saved to: data/clean_data\Seriousness check.csv
# Cleaned CSV saved to: data/clean_data\Skin fold.csv
# Cleaned CSV saved to: data/clean_data\Social buffering.csv
# Cleaned CSV saved to: data/clean_data\Social neuroscience.csv
# Cleaned CSV saved to: data/clean_data\Social science.csv
# Cleaned CSV saved to: data/clean_data\Social services.csv
# Cleaned CSV saved to: data/clean_data\Social simulation.csv
# Cleaned CSV saved to: data/clean_data\Social studies.csv
# Cleaned CSV saved to: data/clean_data\Social work management.csv
# Cleaned CSV saved to: data/clean_data\Social work.csv
# Cleaned CSV saved to: data/clean_data\Spatial turn.csv
# Cleaned CSV saved to: data/clean_data\Splanchnocranium.csv
# Cleaned CSV saved to: data/clean_data\Stafne bone cavity.csv
# Cleaned CSV saved to: data/clean_data\Standard social science model.csv
# Cleaned CSV saved to: data/clean_data\Sternal foramen.csv
# Cleaned CSV saved to: data/clean_data\Subspecialty.csv
# Cleaned CSV saved to: data/clean_data\Superficial cervical fascia.csv
# Cleaned CSV saved to: data/clean_data\Superior thoracic aperture.csv
# Cleaned CSV saved to: data/clean_data\Surface anatomy.csv
# Cleaned CSV saved to: data/clean_data\Table of epithelia of human organs.csv
# Cleaned CSV saved to: data/clean_data\Template_Social sciences.csv
# Cleaned CSV saved to: data/clean_data\Terminologia Anatomica.csv
# Cleaned CSV saved to: data/clean_data\Terminology of alternative medicine.csv
# Cleaned CSV saved to: data/clean_data\Terry Collection.csv
# Cleaned CSV saved to: data/clean_data\The arts and politics.csv
# Cleaned CSV saved to: data/clean_data\The body in traditional Chinese medicine.csv
# Cleaned CSV saved to: data/clean_data\The Type Mapping System.csv
# Cleaned CSV saved to: data/clean_data\Three Principles Psychology.csv
# Cleaned CSV saved to: data/clean_data\Travel medicine.csv
# Cleaned CSV saved to: data/clean_data\Triological Society.csv
# Cleaned CSV saved to: data/clean_data\Trochanter.csv
# Cleaned CSV saved to: data/clean_data\Tubercle.csv
# Cleaned CSV saved to: data/clean_data\Universal health care.csv
# Cleaned CSV saved to: data/clean_data\UPRRP College of Natural Sciences.csv
# Cleaned CSV saved to: data/clean_data\Urinary anti-infective agent.csv
# Cleaned CSV saved to: data/clean_data\Vena comitans.csv
# Cleaned CSV saved to: data/clean_data\Venereology.csv
# Cleaned CSV saved to: data/clean_data\Vesicouterine pouch.csv
# Cleaned CSV saved to: data/clean_data\Vicarious mediation and vicarious functioning.csv
# Cleaned CSV saved to: data/clean_data\Viscerocranium.csv
# Cleaned CSV saved to: data/clean_data\Visible Embryo Project.csv
# Cleaned CSV saved to: data/clean_data\Visible Human Project.csv
# Cleaned CSV saved to: data/clean_data\Visual anthropology.csv
# Cleaned CSV saved to: data/clean_data\Visual ethnography.csv
# Cleaned CSV saved to: data/clean_data\Vyavahāramālā.csv
# Cleaned CSV saved to: data/clean_data\War studies.csv
# Cleaned CSV saved to: data/clean_data\Wenis.csv
# Cleaned CSV saved to: data/clean_data\Wikipedia_Contents_Natural and physical sciences.csv
# Cleaned CSV saved to: data/clean_data\Youth culture.csv
# Cleaned CSV saved to: data/clean_data\Youth intervention.csv
# Cleaned CSV saved to: data/clean_data\Youth services.csv
# Cleaned CSV saved to: data/clean_data\Youth studies.csv
# Cleaned CSV saved to: data/clean_data\Zemiology.csv

# %%
import os
import pandas as pd
import shutil

def remove_empty_csvs_and_copy(input_folder, output_folder):
    """
    Remove empty CSV files (with only Title and Content columns and no data) from the input folder
    and copy the valid ones to the output folder.
    """
    # Check if output folder exists, if not create it
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Iterate over all CSV files in the input folder
    for file_name in os.listdir(input_folder):
        if file_name.endswith('.csv'):
            input_file = os.path.join(input_folder, file_name)
            df = pd.read_csv(input_file)

            # Check if the CSV file contains only the 'Title' and 'Content' columns and has no data
            if df.empty or df['Content'].isnull().all() or df['Content'].str.strip().eq('').all():
                print(f"Deleting empty file: {input_file}")
                os.remove(input_file)  # Remove the file if it's empty or has no data
            else:
                # Copy the valid file to the output folder
                output_file = os.path.join(output_folder, file_name)
                shutil.copy(input_file, output_file)  # Copy instead of move
                print(f"Copied valid file to: {output_file}")

# Define the input and output folders
input_folder = 'data/clean_data'
output_folder = 'data/content_data'

# Remove empty CSVs and copy valid ones to the content_data folder
remove_empty_csvs_and_copy(input_folder, output_folder)
# Out:
# Copied valid file to: data/content_data\Abdomen.csv
# Copied valid file to: data/content_data\Achilles tendon.csv
# Copied valid file to: data/content_data\Adductor hiatus.csv
# Copied valid file to: data/content_data\Administrative history.csv
# Copied valid file to: data/content_data\Allergist.csv
# Copied valid file to: data/content_data\Alveolus.csv
# Copied valid file to: data/content_data\Amniotic sac.csv
# Copied valid file to: data/content_data\Anatomical terminology.csv
# Copied valid file to: data/content_data\Anatomical terms of bone.csv
# Copied valid file to: data/content_data\Anatomical terms of muscle.csv
# Copied valid file to: data/content_data\Anatomical terms of neuroanatomy.csv
# Copied valid file to: data/content_data\Anatomy Charts of the Arabs.csv
# Deleting empty file: data/clean_data\Anatomy of human.csv
# Copied valid file to: data/content_data\Animal studies.csv
# Copied valid file to: data/content_data\Anorectal canal.csv
# Copied valid file to: data/content_data\Anthropocene Working Group.csv
# Copied valid file to: data/content_data\Anthropomaximology.csv
# Copied valid file to: data/content_data\Anthropometry.csv
# Deleting empty file: data/clean_data\Anti-aging medicine.csv
# Copied valid file to: data/content_data\Anti-asthmatic agent.csv
# Copied valid file to: data/content_data\Aortopulmonary space.csv
# Copied valid file to: data/content_data\Ape hand deformity.csv
# Copied valid file to: data/content_data\Apollo's belt.csv
# Copied valid file to: data/content_data\Arthrology.csv
# Copied valid file to: data/content_data\Ascribed characteristics.csv
# Copied valid file to: data/content_data\Axial skeleton.csv
# Copied valid file to: data/content_data\Beclard Triangle.csv
# Copied valid file to: data/content_data\Belief congruence.csv
# Copied valid file to: data/content_data\Bioculture.csv
# Copied valid file to: data/content_data\Biomedical sciences.csv
# Copied valid file to: data/content_data\Body Worlds.csv
# Copied valid file to: data/content_data\Brain connectivity estimators.csv
# Copied valid file to: data/content_data\Breastmilk medicine.csv
# Copied valid file to: data/content_data\Bregma.csv
# Copied valid file to: data/content_data\Cancer exodus hypothesis.csv
# Deleting empty file: data/clean_data\Category_Absent body parts.csv
# Deleting empty file: data/clean_data\Category_Academic health science centres.csv
# Deleting empty file: data/clean_data\Category_Addiction medicine.csv
# Copied valid file to: data/content_data\Category_Alternative medicine.csv
# Copied valid file to: data/content_data\Category_Amniotic sac.csv
# Copied valid file to: data/content_data\Category_Anatomical variations.csv
# Copied valid file to: data/content_data\Category_Anatomy named for one who described it.csv
# Copied valid file to: data/content_data\Category_Andrology.csv
# Copied valid file to: data/content_data\Category_Anesthesiology.csv
# Copied valid file to: data/content_data\Category_Angiology.csv
# Copied valid file to: data/content_data\Category_Anthropology.csv
# Deleting empty file: data/clean_data\Category_Anthropometry.csv
# Copied valid file to: data/content_data\Category_Archaeology.csv
# Deleting empty file: data/clean_data\Category_Arthrology.csv
# Copied valid file to: data/content_data\Category_Audiology.csv
# Deleting empty file: data/clean_data\Category_Auxology.csv
# Copied valid file to: data/content_data\Category_Aviation medicine.csv
# Copied valid file to: data/content_data\Category_Back anatomy.csv
# Deleting empty file: data/clean_data\Category_Behavioural sciences.csv
# Deleting empty file: data/clean_data\Category_Biological engineering.csv
# Deleting empty file: data/clean_data\Category_Biomedicine.csv
# Copied valid file to: data/content_data\Category_Biotechnology.csv
# Copied valid file to: data/content_data\Category_Branches of medical specialties.csv
# Copied valid file to: data/content_data\Category_Branches of psychology.csv
# Deleting empty file: data/clean_data\Category_Cardiology.csv
# Deleting empty file: data/clean_data\Category_Cause (medicine).csv
# Deleting empty file: data/clean_data\Category_Chemicals in medicine.csv
# Deleting empty file: data/clean_data\Category_Circulatory system.csv
# Deleting empty file: data/clean_data\Category_Clinical medicine.csv
# Copied valid file to: data/content_data\Category_Clinical pharmacology.csv
# Copied valid file to: data/content_data\Category_Cognitive science.csv
# Copied valid file to: data/content_data\Category_Communication design.csv
# Deleting empty file: data/clean_data\Category_Computational social science.csv
# Copied valid file to: data/content_data\Category_Computer-mediated communication.csv
# Deleting empty file: data/clean_data\Category_Dentistry.csv
# Deleting empty file: data/clean_data\Category_Dermatology.csv
# Deleting empty file: data/clean_data\Category_Development studies.csv
# Copied valid file to: data/content_data\Category_Earth sciences.csv
# Deleting empty file: data/clean_data\Category_Economics.csv
# Deleting empty file: data/clean_data\Category_Education theory.csv
# Copied valid file to: data/content_data\Category_Emergency medicine.csv
# Copied valid file to: data/content_data\Category_Emotion.csv
# Copied valid file to: data/content_data\Category_Endocrinology.csv
# Deleting empty file: data/clean_data\Category_Environmental social science.csv
# Deleting empty file: data/clean_data\Category_Epidemiology.csv
# Copied valid file to: data/content_data\Category_Euthenics.csv
# Deleting empty file: data/clean_data\Category_Facial features.csv
# Copied valid file to: data/content_data\Category_Gastroenterology.csv
# Copied valid file to: data/content_data\Category_General practice.csv
# Copied valid file to: data/content_data\Category_Geriatrics.csv
# Deleting empty file: data/clean_data\Category_GLAM (culture and information).csv
# Deleting empty file: data/clean_data\Category_Glands.csv
# Deleting empty file: data/clean_data\Category_Gynaecology.csv
# Deleting empty file: data/clean_data\Category_Health physicists.csv
# Copied valid file to: data/content_data\Category_Health sciences by country.csv
# Copied valid file to: data/content_data\Category_Health sciences organizations.csv
# Copied valid file to: data/content_data\Category_Health sciences publications.csv
# Deleting empty file: data/clean_data\Category_Health sciences schools.csv
# Deleting empty file: data/clean_data\Category_Health-related conspiracy theories.csv
# Copied valid file to: data/content_data\Category_Hematology.csv
# Deleting empty file: data/clean_data\Category_Hepatology.csv
# Copied valid file to: data/content_data\Category_History of medical and surgical specialties.csv
# Copied valid file to: data/content_data\Category_History of medicine.csv
# Deleting empty file: data/clean_data\Category_History of psychology.csv
# Deleting empty file: data/clean_data\Category_History of social sciences.csv
# Copied valid file to: data/content_data\Category_History.csv
# Deleting empty file: data/clean_data\Category_Hospital medicine.csv
# Deleting empty file: data/clean_data\Category_Human anatomy by organ.csv
# Copied valid file to: data/content_data\Category_Human anatomy by system.csv
# Deleting empty file: data/clean_data\Category_Human anatomy museums.csv
# Copied valid file to: data/content_data\Category_Human development.csv
# Deleting empty file: data/clean_data\Category_Human geography.csv
# Copied valid file to: data/content_data\Category_Human head and neck.csv
# Copied valid file to: data/content_data\Category_Human sciences.csv
# Copied valid file to: data/content_data\Category_Human size.csv
# Deleting empty file: data/clean_data\Category_Human skin.csv
# Deleting empty file: data/clean_data\Category_Human surface anatomy.csv
# Deleting empty file: data/clean_data\Category_ILAE Wikipedia Project.csv
# Copied valid file to: data/content_data\Category_Immunology.csv
# Copied valid file to: data/content_data\Category_Intensive care medicine.csv
# Deleting empty file: data/clean_data\Category_Interdisciplinary subfields of medicine.csv
# Deleting empty file: data/clean_data\Category_Internal medicine.csv
# Copied valid file to: data/content_data\Category_Intersex and medicine.csv
# Copied valid file to: data/content_data\Category_Labor studies.csv
# Deleting empty file: data/clean_data\Category_Library and information science.csv
# Deleting empty file: data/clean_data\Category_Life sciences.csv
# Deleting empty file: data/clean_data\Category_Limbs (anatomy).csv
# Deleting empty file: data/clean_data\Category_Linguistics.csv
# Deleting empty file: data/clean_data\Category_Lists of human anatomical features.csv
# Deleting empty file: data/clean_data\Category_Media studies.csv
# Deleting empty file: data/clean_data\Category_Medical activism.csv
# Deleting empty file: data/clean_data\Category_Medical and health organizations by subject.csv
# Deleting empty file: data/clean_data\Category_Medical and health organizations.csv
# Copied valid file to: data/content_data\Category_Medical aspects of death.csv
# Copied valid file to: data/content_data\Category_Medical associations.csv
# Deleting empty file: data/clean_data\Category_Medical diplomacy.csv
# Copied valid file to: data/content_data\Category_Medical doctors by specialty.csv
# Copied valid file to: data/content_data\Category_Medical education by branch.csv
# Deleting empty file: data/clean_data\Category_Medical education.csv
# Deleting empty file: data/clean_data\Category_Medical genetics.csv
# Deleting empty file: data/clean_data\Category_Medical humanities.csv
# Deleting empty file: data/clean_data\Category_Medical lists.csv
# Deleting empty file: data/clean_data\Category_Medical literature by subject.csv
# Deleting empty file: data/clean_data\Category_Medical microbiology.csv
# Copied valid file to: data/content_data\Category_Medical phenomena.csv
# Deleting empty file: data/clean_data\Category_Medical prevention.csv
# Deleting empty file: data/clean_data\Category_Medical research.csv
# Deleting empty file: data/clean_data\Category_Medical statistics.csv
# Deleting empty file: data/clean_data\Category_Medical symbols.csv
# Deleting empty file: data/clean_data\Category_Medical technology.csv
# Copied valid file to: data/content_data\Category_Medical terminology.csv
# Deleting empty file: data/clean_data\Category_Medical volunteerism.csv
# Deleting empty file: data/clean_data\Category_Medicine awards.csv
# Deleting empty file: data/clean_data\Category_Medicine by century.csv
# Deleting empty file: data/clean_data\Category_Medicine by city.csv
# Deleting empty file: data/clean_data\Category_Medicine by country subdivision.csv
# Copied valid file to: data/content_data\Category_Medicine by country.csv
# Copied valid file to: data/content_data\Category_Medicine by decade.csv
# Deleting empty file: data/clean_data\Category_Medicine by dependent territory.csv
# Copied valid file to: data/content_data\Category_Medicine by year.csv
# Deleting empty file: data/clean_data\Category_Medicine in society.csv
# Copied valid file to: data/content_data\Category_Medicine stubs.csv
# Copied valid file to: data/content_data\Category_Medicine.csv
# Deleting empty file: data/clean_data\Category_Men's health.csv
# Copied valid file to: data/content_data\Category_Midwifery.csv
# Copied valid file to: data/content_data\Category_Military medicine.csv
# Copied valid file to: data/content_data\Category_Military science.csv
# Deleting empty file: data/clean_data\Category_Modern studies.csv
# Deleting empty file: data/clean_data\Category_Natural history.csv
# Deleting empty file: data/clean_data\Category_Natural science stubs.csv
# Copied valid file to: data/content_data\Category_Natural scientists.csv
# Deleting empty file: data/clean_data\Category_Nephrology.csv
# Deleting empty file: data/clean_data\Category_Network science.csv
# Deleting empty file: data/clean_data\Category_Neuroanatomy.csv
# Copied valid file to: data/content_data\Category_Neurology.csv
# Deleting empty file: data/clean_data\Category_Nuclear medicine.csv
# Copied valid file to: data/content_data\Category_Nursing specialties.csv
# Deleting empty file: data/clean_data\Category_Nursing.csv
# Copied valid file to: data/content_data\Category_Obstetrics.csv
# Copied valid file to: data/content_data\Category_Occupational medicine.csv
# Copied valid file to: data/content_data\Category_Oncology.csv
# Copied valid file to: data/content_data\Category_Ophthalmology.csv
# Deleting empty file: data/clean_data\Category_Orthopedics.csv
# Deleting empty file: data/clean_data\Category_Otorhinolaryngology.csv
# Copied valid file to: data/content_data\Category_Parasitology.csv
# Deleting empty file: data/clean_data\Category_Pathology.csv
# Deleting empty file: data/clean_data\Category_Peace and conflict studies.csv
# Copied valid file to: data/content_data\Category_Pediatrics.csv
# Deleting empty file: data/clean_data\Category_Pharmaceutical sciences.csv
# Copied valid file to: data/content_data\Category_Pharmacy.csv
# Deleting empty file: data/clean_data\Category_Philosophy of psychology.csv
# Copied valid file to: data/content_data\Category_Philosophy of social science.csv
# Deleting empty file: data/clean_data\Category_Physical sciences.csv
# Copied valid file to: data/content_data\Category_Podiatry.csv
# Copied valid file to: data/content_data\Category_Political science.csv
# Copied valid file to: data/content_data\Category_Popular psychology.csv
# Deleting empty file: data/clean_data\Category_Practice of medicine.csv
# Deleting empty file: data/clean_data\Category_Prescription of drugs.csv
# Deleting empty file: data/clean_data\Category_Preventive medicine.csv
# Deleting empty file: data/clean_data\Category_Prison healthcare.csv
# Copied valid file to: data/content_data\Category_Psychiatry.csv
# Deleting empty file: data/clean_data\Category_Psychological concepts.csv
# Deleting empty file: data/clean_data\Category_Psychological effects.csv
# Deleting empty file: data/clean_data\Category_Psychological methodology.csv
# Deleting empty file: data/clean_data\Category_Psychological schools.csv
# Copied valid file to: data/content_data\Category_Psychological testing.csv
# Deleting empty file: data/clean_data\Category_Psychological theories.csv
# Copied valid file to: data/content_data\Category_Psychologists.csv
# Deleting empty file: data/clean_data\Category_Psychology awards.csv
# Deleting empty file: data/clean_data\Category_Psychology controversies.csv
# Deleting empty file: data/clean_data\Category_Psychology education.csv
# Deleting empty file: data/clean_data\Category_Psychology images.csv
# Deleting empty file: data/clean_data\Category_Psychology lists.csv
# Deleting empty file: data/clean_data\Category_Psychology organizations.csv
# Copied valid file to: data/content_data\Category_Psychology portal.csv
# Deleting empty file: data/clean_data\Category_Psychology stubs.csv
# Deleting empty file: data/clean_data\Category_Psychology templates.csv
# Deleting empty file: data/clean_data\Category_Psychology writers.csv
# Copied valid file to: data/content_data\Category_Psychology.csv
# Deleting empty file: data/clean_data\Category_Public health.csv
# Copied valid file to: data/content_data\Category_Pulmonology.csv
# Copied valid file to: data/content_data\Category_Radiology.csv
# Deleting empty file: data/clean_data\Category_Railway surgery.csv
# Deleting empty file: data/clean_data\Category_Regional science.csv
# Deleting empty file: data/clean_data\Category_Rehabilitation medicine.csv
# Deleting empty file: data/clean_data\Category_Religion and medicine.csv
# Copied valid file to: data/content_data\Category_Rheumatology.csv
# Copied valid file to: data/content_data\Category_Security studies.csv
# Copied valid file to: data/content_data\Category_Self-portraiture.csv
# Copied valid file to: data/content_data\Category_Seventh-day Adventists in health science.csv
# Deleting empty file: data/clean_data\Category_Sexual health.csv
# Deleting empty file: data/clean_data\Category_Sexual orientation and psychology.csv
# Deleting empty file: data/clean_data\Category_Sleep medicine.csv
# Deleting empty file: data/clean_data\Category_Social ideologies.csv
# Deleting empty file: data/clean_data\Category_Social physics.csv
# Deleting empty file: data/clean_data\Category_Social research.csv
# Deleting empty file: data/clean_data\Category_Social science disambiguation pages.csv
# Deleting empty file: data/clean_data\Category_Social science fiction.csv
# Copied valid file to: data/content_data\Category_Social science indices.csv
# Deleting empty file: data/clean_data\Category_Social science methodology.csv
# Deleting empty file: data/clean_data\Category_Social science occupations.csv
# Deleting empty file: data/clean_data\Category_Social science stubs.csv
# Deleting empty file: data/clean_data\Category_Social sciences awards.csv
# Deleting empty file: data/clean_data\Category_Social sciences lists.csv
# Deleting empty file: data/clean_data\Category_Social sciences literature.csv
# Copied valid file to: data/content_data\Category_Social sciences organizations.csv
# Deleting empty file: data/clean_data\Category_Social sciences terminology.csv
# Deleting empty file: data/clean_data\Category_Social scientists.csv
# Deleting empty file: data/clean_data\Category_Social theories.csv
# Copied valid file to: data/content_data\Category_Social work.csv
# Copied valid file to: data/content_data\Category_Sociology.csv
# Deleting empty file: data/clean_data\Category_Space medicine.csv
# Deleting empty file: data/clean_data\Category_Sports medicine.csv
# Copied valid file to: data/content_data\Category_Stomatologists.csv
# Copied valid file to: data/content_data\Category_Supernumerary body parts.csv
# Deleting empty file: data/clean_data\Category_Surgery.csv
# Deleting empty file: data/clean_data\Category_Thanatology.csv
# Deleting empty file: data/clean_data\Category_Theory of medicine.csv
# Copied valid file to: data/content_data\Category_Thermal medicine.csv
# Deleting empty file: data/clean_data\Category_Toxicology.csv
# Deleting empty file: data/clean_data\Category_Translational medicine.csv
# Deleting empty file: data/clean_data\Category_Transplantation medicine.csv
# Copied valid file to: data/content_data\Category_Tropical medicine.csv
# Deleting empty file: data/clean_data\Category_Urban planning.csv
# Copied valid file to: data/content_data\Category_Urinary system.csv
# Copied valid file to: data/content_data\Category_Urology.csv
# Deleting empty file: data/clean_data\Category_Veterinary medicine.csv
# Deleting empty file: data/clean_data\Category_Women and psychology.csv
# Deleting empty file: data/clean_data\Category_Women in medicine.csv
# Deleting empty file: data/clean_data\Category_Women's health.csv
# Deleting empty file: data/clean_data\Category_Works about medicine.csv
# Deleting empty file: data/clean_data\Category_Works about psychology.csv
# Copied valid file to: data/content_data\Cavoatrial junction.csv
# Copied valid file to: data/content_data\Center for Anatomy of the Charité.csv
# Copied valid file to: data/content_data\Cervical artery dissection.csv
# Copied valid file to: data/content_data\Cervical rib.csv
# Copied valid file to: data/content_data\Change and continuity.csv
# Copied valid file to: data/content_data\Civil surgeon.csv
# Copied valid file to: data/content_data\Clinical handover.csv
# Copied valid file to: data/content_data\Clinical physiology.csv
# Copied valid file to: data/content_data\Coccygeal glomus.csv
# Copied valid file to: data/content_data\Collective mental state.csv
# Copied valid file to: data/content_data\Collusion (psychology).csv
# Copied valid file to: data/content_data\Compensatory growth (organ).csv
# Copied valid file to: data/content_data\Composition of the human body.csv
# Copied valid file to: data/content_data\Computational social science.csv
# Copied valid file to: data/content_data\Conflict and Catastrophe Medicine.csv
# Copied valid file to: data/content_data\Confocal endoscopy.csv
# Copied valid file to: data/content_data\Corona of glans penis.csv
# Copied valid file to: data/content_data\Counterphobic attitude.csv
# Copied valid file to: data/content_data\Criminology.csv
# Copied valid file to: data/content_data\Cultural studies.csv
# Copied valid file to: data/content_data\Darwin's tubercle.csv
# Copied valid file to: data/content_data\Data Colada.csv
# Copied valid file to: data/content_data\Dental anatomy.csv
# Copied valid file to: data/content_data\Dermatocranium.csv
# Copied valid file to: data/content_data\Desjardins' point.csv
# Copied valid file to: data/content_data\Diabetes self-management.csv
# Copied valid file to: data/content_data\Distributive justice.csv
# Deleting empty file: data/clean_data\Diving Medical Examiner.csv
# Deleting empty file: data/clean_data\Diving Medical Practitioner.csv
# Copied valid file to: data/content_data\Diving medicine.csv
# Copied valid file to: data/content_data\Doctor of Social Science.csv
# Copied valid file to: data/content_data\Dorsal body cavity.csv
# Copied valid file to: data/content_data\Dorsal pancreatic agenesis.csv
# Copied valid file to: data/content_data\Drone-Enhanced Emergency Medical Services.csv
# Copied valid file to: data/content_data\Eardrum.csv
# Copied valid file to: data/content_data\Efficient Voter Rule.csv
# Copied valid file to: data/content_data\Emotion.csv
# Copied valid file to: data/content_data\Enchantment (social sciences).csv
# Copied valid file to: data/content_data\Endocranium.csv
# Copied valid file to: data/content_data\Environmental medicine.csv
# Copied valid file to: data/content_data\Epidemiology.csv
# Copied valid file to: data/content_data\Episternal ossicles.csv
# Copied valid file to: data/content_data\Estrogenic fat.csv
# Copied valid file to: data/content_data\Eustachian tube.csv
# Copied valid file to: data/content_data\Evelyn tables.csv
# Copied valid file to: data/content_data\Exercise medicine.csv
# Copied valid file to: data/content_data\Extensor retinaculum of the hand.csv
# Copied valid file to: data/content_data\Eyelid.csv
# Copied valid file to: data/content_data\Fascial Net Plastination Project.csv
# Copied valid file to: data/content_data\Fascial spaces of the head and neck.csv
# Copied valid file to: data/content_data\Fingerprint.csv
# Copied valid file to: data/content_data\Fontanelle.csv
# Copied valid file to: data/content_data\Foramen singulare.csv
# Copied valid file to: data/content_data\Force-field analysis.csv
# Copied valid file to: data/content_data\Foreskin.csv
# Copied valid file to: data/content_data\Fossa navicularis magna.csv
# Copied valid file to: data/content_data\Geography.csv
# Copied valid file to: data/content_data\Glabella.csv
# Copied valid file to: data/content_data\Global health.csv
# Copied valid file to: data/content_data\Groin.csv
# Copied valid file to: data/content_data\Growing teeth.csv
# Deleting empty file: data/clean_data\Gulbenkian commission.csv
# Copied valid file to: data/content_data\Health care.csv
# Copied valid file to: data/content_data\Health crisis.csv
# Copied valid file to: data/content_data\Health equity.csv
# Copied valid file to: data/content_data\Health policy.csv
# Copied valid file to: data/content_data\Health Sciences Descriptors.csv
# Copied valid file to: data/content_data\Health survival paradox.csv
# Copied valid file to: data/content_data\Health system.csv
# Copied valid file to: data/content_data\Heortology.csv
# Copied valid file to: data/content_data\Heterocrine gland.csv
# Copied valid file to: data/content_data\Human back.csv
# Copied valid file to: data/content_data\Human body.csv
# Copied valid file to: data/content_data\Human fat.csv
# Copied valid file to: data/content_data\Human mouth.csv
# Copied valid file to: data/content_data\Human nose.csv
# Copied valid file to: data/content_data\Human penis.csv
# Copied valid file to: data/content_data\Human reproductive system.csv
# Copied valid file to: data/content_data\Human skeleton.csv
# Copied valid file to: data/content_data\Human tooth.csv
# Copied valid file to: data/content_data\Human vestigiality.csv
# Copied valid file to: data/content_data\Humanities, arts, and social sciences.csv
# Copied valid file to: data/content_data\Iliac crest.csv
# Copied valid file to: data/content_data\Imperial College Faculty of Natural Sciences.csv
# Copied valid file to: data/content_data\Inferior frontal junction.csv
# Copied valid file to: data/content_data\Institute of Human Anatomy.csv
# Copied valid file to: data/content_data\Interdental plate.csv
# Copied valid file to: data/content_data\International order.csv
# Copied valid file to: data/content_data\Interoception.csv
# Copied valid file to: data/content_data\Intrascleral plexus.csv
# Copied valid file to: data/content_data\Isotropic bands.csv
# Copied valid file to: data/content_data\Jurisprudence.csv
# Copied valid file to: data/content_data\Kiesselbach's plexus.csv
# Copied valid file to: data/content_data\Kinanthropometry.csv
# Copied valid file to: data/content_data\Koch's triangle.csv
# Copied valid file to: data/content_data\LAMA2 related congenital muscular dystrophy.csv
# Copied valid file to: data/content_data\Lap.csv
# Copied valid file to: data/content_data\Lateral palpebral raphe.csv
# Copied valid file to: data/content_data\Limerence.csv
# Copied valid file to: data/content_data\Lip.csv
# Copied valid file to: data/content_data\List of anatomy mnemonics.csv
# Copied valid file to: data/content_data\List of forms of alternative medicine.csv
# Copied valid file to: data/content_data\List of medical specialty colleges in the United States.csv
# Copied valid file to: data/content_data\Little finger.csv
# Copied valid file to: data/content_data\LY-2365109.csv
# Copied valid file to: data/content_data\Macro social work.csv
# Copied valid file to: data/content_data\Marginal sinus.csv
# Copied valid file to: data/content_data\Marionette lines.csv
# Copied valid file to: data/content_data\Masculine fragility.csv
# Copied valid file to: data/content_data\Mass gathering medicine.csv
# Copied valid file to: data/content_data\Medical entomology.csv
# Copied valid file to: data/content_data\Medical specialty.csv
# Copied valid file to: data/content_data\Medical statistics.csv
# Copied valid file to: data/content_data\Medicine.csv
# Copied valid file to: data/content_data\Mentum.csv
# Copied valid file to: data/content_data\Methodological nationalism.csv
# Copied valid file to: data/content_data\Middle ear.csv
# Copied valid file to: data/content_data\Mobilities.csv
# Copied valid file to: data/content_data\Modern Studies.csv
# Copied valid file to: data/content_data\Motivation.csv
# Copied valid file to: data/content_data\Musical escapism.csv
# Copied valid file to: data/content_data\My Dao method.csv
# Copied valid file to: data/content_data\Natural science.csv
# Copied valid file to: data/content_data\Natural Sciences Collections Association.csv
# Copied valid file to: data/content_data\Nature (journal).csv
# Copied valid file to: data/content_data\Neanderthal anatomy.csv
# Copied valid file to: data/content_data\Neurocranium.csv
# Copied valid file to: data/content_data\Neuroepigenetics.csv
# Copied valid file to: data/content_data\Neurosurgical anesthesia.csv
# Copied valid file to: data/content_data\Normativity.csv
# Copied valid file to: data/content_data\Nudity.csv
# Copied valid file to: data/content_data\Nurture.csv
# Copied valid file to: data/content_data\Nutritional psychiatry.csv
# Copied valid file to: data/content_data\Obshchestvovedeniye.csv
# Copied valid file to: data/content_data\Occupational medicine.csv
# Copied valid file to: data/content_data\Occupational science.csv
# Copied valid file to: data/content_data\Oncology.csv
# Copied valid file to: data/content_data\Open Path Collective.csv
# Copied valid file to: data/content_data\Operationalization.csv
# Copied valid file to: data/content_data\Oral and maxillofacial surgery.csv
# Copied valid file to: data/content_data\Otorhinolaryngology.csv
# Copied valid file to: data/content_data\Outline of health sciences.csv
# Copied valid file to: data/content_data\Outline of human anatomy.csv
# Copied valid file to: data/content_data\Outline of medicine.csv
# Copied valid file to: data/content_data\Outline of natural science.csv
# Copied valid file to: data/content_data\Outline of psychology.csv
# Copied valid file to: data/content_data\Outline of social science.csv
# Copied valid file to: data/content_data\Outline of the human nervous system.csv
# Copied valid file to: data/content_data\Paedology.csv
# Copied valid file to: data/content_data\Palmar aponeurosis.csv
# Copied valid file to: data/content_data\Parasitology.csv
# Copied valid file to: data/content_data\Passionate and companionate love.csv
# Copied valid file to: data/content_data\Pectoral muscles.csv
# Copied valid file to: data/content_data\Pediatric endocrinology.csv
# Copied valid file to: data/content_data\Pelvic tilt.csv
# Copied valid file to: data/content_data\Perceptual vigilance.csv
# Copied valid file to: data/content_data\Performance science.csv
# Copied valid file to: data/content_data\Personality neuroscience.csv
# Copied valid file to: data/content_data\Petrous portion.csv
# Copied valid file to: data/content_data\Phoniatrics.csv
# Copied valid file to: data/content_data\Plastic surgery.csv
# Copied valid file to: data/content_data\Platform capitalism.csv
# Copied valid file to: data/content_data\Poison exon.csv
# Copied valid file to: data/content_data\Population health.csv
# Deleting empty file: data/clean_data\Portal_Medicine.csv
# Deleting empty file: data/clean_data\Portal_Psychology.csv
# Copied valid file to: data/content_data\Positive health.csv
# Copied valid file to: data/content_data\Praxeology.csv
# Copied valid file to: data/content_data\Prodromus.csv
# Copied valid file to: data/content_data\Progress.csv
# Copied valid file to: data/content_data\Psychiatry.csv
# Copied valid file to: data/content_data\Psychologist.csv
# Copied valid file to: data/content_data\Psychology.csv
# Copied valid file to: data/content_data\Psychosomatic medicine.csv
# Copied valid file to: data/content_data\Ptosis (chin).csv
# Copied valid file to: data/content_data\Public health.csv
# Copied valid file to: data/content_data\Publicly funded health care.csv
# Copied valid file to: data/content_data\Quantum social science.csv
# Copied valid file to: data/content_data\Radiographic anatomy.csv
# Copied valid file to: data/content_data\Railway surgery.csv
# Copied valid file to: data/content_data\Rangeland management.csv
# Copied valid file to: data/content_data\Representative sequences.csv
# Copied valid file to: data/content_data\Resilience week.csv
# Copied valid file to: data/content_data\Rhombus of Michaelis.csv
# Copied valid file to: data/content_data\Right to health.csv
# Copied valid file to: data/content_data\RNU4-2 syndrome.csv
# Copied valid file to: data/content_data\Rural health.csv
# Deleting empty file: data/clean_data\Samhällsvetenskapsprogrammet.csv
# Copied valid file to: data/content_data\Scalene muscles.csv
# Copied valid file to: data/content_data\Science and technology studies.csv
# Copied valid file to: data/content_data\Seriousness check.csv
# Copied valid file to: data/content_data\Skin fold.csv
# Copied valid file to: data/content_data\Social buffering.csv
# Copied valid file to: data/content_data\Social neuroscience.csv
# Copied valid file to: data/content_data\Social science.csv
# Copied valid file to: data/content_data\Social services.csv
# Copied valid file to: data/content_data\Social simulation.csv
# Copied valid file to: data/content_data\Social studies.csv
# Copied valid file to: data/content_data\Social work management.csv
# Copied valid file to: data/content_data\Social work.csv
# Copied valid file to: data/content_data\Spatial turn.csv
# Copied valid file to: data/content_data\Splanchnocranium.csv
# Deleting empty file: data/clean_data\Stafne bone cavity.csv
# Copied valid file to: data/content_data\Standard social science model.csv
# Copied valid file to: data/content_data\Sternal foramen.csv
# Copied valid file to: data/content_data\Subspecialty.csv
# Copied valid file to: data/content_data\Superficial cervical fascia.csv
# Copied valid file to: data/content_data\Superior thoracic aperture.csv
# Copied valid file to: data/content_data\Surface anatomy.csv
# Copied valid file to: data/content_data\Table of epithelia of human organs.csv
# Deleting empty file: data/clean_data\Template_Social sciences.csv
# Copied valid file to: data/content_data\Terminologia Anatomica.csv
# Copied valid file to: data/content_data\Terminology of alternative medicine.csv
# Copied valid file to: data/content_data\Terry Collection.csv
# Copied valid file to: data/content_data\The arts and politics.csv
# Copied valid file to: data/content_data\The body in traditional Chinese medicine.csv
# Copied valid file to: data/content_data\The Type Mapping System.csv
# Copied valid file to: data/content_data\Three Principles Psychology.csv
# Copied valid file to: data/content_data\Travel medicine.csv
# Copied valid file to: data/content_data\Triological Society.csv
# Copied valid file to: data/content_data\Trochanter.csv
# Copied valid file to: data/content_data\Tubercle.csv
# Copied valid file to: data/content_data\Universal health care.csv
# Copied valid file to: data/content_data\UPRRP College of Natural Sciences.csv
# Copied valid file to: data/content_data\Urinary anti-infective agent.csv
# Copied valid file to: data/content_data\Vena comitans.csv
# Copied valid file to: data/content_data\Venereology.csv
# Copied valid file to: data/content_data\Vesicouterine pouch.csv
# Copied valid file to: data/content_data\Vicarious mediation and vicarious functioning.csv
# Copied valid file to: data/content_data\Viscerocranium.csv
# Copied valid file to: data/content_data\Visible Embryo Project.csv
# Copied valid file to: data/content_data\Visible Human Project.csv
# Copied valid file to: data/content_data\Visual anthropology.csv
# Copied valid file to: data/content_data\Visual ethnography.csv
# Copied valid file to: data/content_data\Vyavahāramālā.csv
# Copied valid file to: data/content_data\War studies.csv
# Copied valid file to: data/content_data\Wenis.csv
# Deleting empty file: data/clean_data\Wikipedia_Contents_Natural and physical sciences.csv
# Copied valid file to: data/content_data\Youth culture.csv
# Copied valid file to: data/content_data\Youth intervention.csv
# Copied valid file to: data/content_data\Youth services.csv
# Copied valid file to: data/content_data\Youth studies.csv
# Copied valid file to: data/content_data\Zemiology.csv

# %% [markdown]
# # Summarize the content
# To handle long text, we can:
#
# - Split the content into smaller chunks.
# - Summarize each chunk individually.
# - Combine the summaries for each chunk into one final summary.

# %%
import os
import pandas as pd
from transformers import pipeline

# Initialize the Hugging Face summarization model
summarizer = pipeline("summarization", model="facebook/bart-large-cnn")

def split_text_into_chunks(text, max_tokens=512):
    """
    Splits the text into chunks that fit within the token limit.
    """
    # Tokenize the text and split into chunks
    words = text.split()
    chunks = []
    current_chunk = []

    # Add words until we reach the max token limit
    for word in words:
        current_chunk.append(word)
        if len(' '.join(current_chunk)) > max_tokens:
            chunks.append(' '.join(current_chunk[:-1]))  # Add the chunk without the last word
            current_chunk = [current_chunk[-1]]  # Start a new chunk with the last word

    if current_chunk:  # Add any remaining chunk
        chunks.append(' '.join(current_chunk))

    return chunks

# %%
def summarize_text(text):
    """
    Summarizes the given text by splitting it into smaller chunks if necessary.
    Dynamically adjusts the max_length based on the length of the input.
    """
    # Calculate the length of the input text in terms of tokens/words
    input_length = len(text.split())
    
    # Set max_length to be at most 50% of input length, but ensure it's not too large
    max_summary_length = min(150, max(50, input_length // 2))  # Prevents too long summaries

    # If the text is too long (more than 512 words), split it into smaller chunks
    if input_length > 512:
        chunks = split_text_into_chunks(text)
        summaries = []
        for chunk in chunks:
            summary = summarizer(chunk, max_length=max_summary_length, min_length=50, do_sample=False)[0]['summary_text']
            summaries.append(summary)
        return ' '.join(summaries)  # Combine all chunk summaries
    else:
        # If text is short enough, summarize it directly
        return summarizer(text, max_length=max_summary_length, min_length=50, do_sample=False)[0]['summary_text']

# %%
def summarize_csv(input_folder, output_folder):
    """
    Read CSV files, apply summarization to the content, and save the summarized data to new CSV files.
    """
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Iterate through all CSV files in the input folder
    for file_name in os.listdir(input_folder):
        if file_name.endswith('.csv'):
            input_file = os.path.join(input_folder, file_name)
            df = pd.read_csv(input_file)

            # Check if the 'Content' column exists
            if 'Content' in df.columns:
                # Apply summarization to each content entry
                df['Content'] = df['Content'].apply(summarize_text)
                
                # Save the summarized data to a new CSV
                output_file = os.path.join(output_folder, f"summarized_{file_name}")
                df.to_csv(output_file, index=False)
                print(f"Summarized CSV saved to: {output_file}")
            else:
                print(f"No 'Content' column in {input_file}. Skipping.")

# Define input and output folders
input_folder = 'data/content_data'  # Folder with content_data
output_folder = 'data/summarized_data'  # Folder where summarized data will be stored

# Summarize all content in the CSV files
summarize_csv(input_folder, output_folder)
# Out:
# Your max_length is set to 150, but your input_length is only 120. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=60)
# Your max_length is set to 150, but your input_length is only 113. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=56)
# Your max_length is set to 150, but your input_length is only 106. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=53)
# Your max_length is set to 150, but your input_length is only 90. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=45)
# Your max_length is set to 150, but your input_length is only 103. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=51)
# Your max_length is set to 150, but your input_length is only 106. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=53)
# Your max_length is set to 150, but your input_length is only 110. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=55)
# Your max_length is set to 150, but your input_length is only 108. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=54)
# Your max_length is set to 150, but your input_length is only 109. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=54)
# Your max_length is set to 150, but your input_length is only 99. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=49)
# Your max_length is set to 150, but your input_length is only 101. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# Your max_length is set to 150, but your input_length is only 100. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# Your max_length is set to 150, but your input_length is only 101. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# Your max_length is set to 150, but your input_length is only 91. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=45)
# Your max_length is set to 150, but your input_length is only 83. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=41)
# Your max_length is set to 150, but your input_length is only 87. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=43)
# Your max_length is set to 150, but your input_length is only 95. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=47)
# Your max_length is set to 150, but your input_length is only 101. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# Your max_length is set to 150, but your input_length is only 112. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=56)
# Your max_length is set to 150, but your input_length is only 110. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=55)
# Your max_length is set to 150, but your input_length is only 105. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=52)
# Your max_length is set to 150, but your input_length is only 115. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=57)
# Your max_length is set to 150, but your input_length is only 112. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=56)
# Your max_length is set to 150, but your input_length is only 113. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=56)
# Your max_length is set to 150, but your input_length is only 98. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=49)
# Your max_length is set to 150, but your input_length is only 112. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=56)
# Your max_length is set to 150, but your input_length is only 113. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=56)
# Your max_length is set to 150, but your input_length is only 97. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=48)
# Your max_length is set to 150, but your input_length is only 108. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=54)
# Your max_length is set to 150, but your input_length is only 105. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=52)
# Your max_length is set to 150, but your input_length is only 41. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=20)
# Your max_length is set to 150, but your input_length is only 107. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=53)
# Summarized CSV saved to: data/summarized_data\summarized_Abdomen.csv
# Your max_length is set to 150, but your input_length is only 107. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=53)
# Your max_length is set to 150, but your input_length is only 106. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=53)
# Your max_length is set to 150, but your input_length is only 97. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=48)
# Your max_length is set to 150, but your input_length is only 110. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=55)
# Your max_length is set to 150, but your input_length is only 111. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=55)
# Your max_length is set to 150, but your input_length is only 101. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# Your max_length is set to 150, but your input_length is only 114. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=57)
# Your max_length is set to 150, but your input_length is only 95. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=47)
# Your max_length is set to 150, but your input_length is only 95. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=47)
# Your max_length is set to 150, but your input_length is only 87. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=43)
# Your max_length is set to 150, but your input_length is only 102. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=51)
# Your max_length is set to 150, but your input_length is only 101. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# Your max_length is set to 150, but your input_length is only 92. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=46)
# Your max_length is set to 150, but your input_length is only 96. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=48)
# Your max_length is set to 150, but your input_length is only 90. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=45)
# Your max_length is set to 150, but your input_length is only 97. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=48)
# Your max_length is set to 150, but your input_length is only 89. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=44)
# Your max_length is set to 150, but your input_length is only 29. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=14)
# Summarized CSV saved to: data/summarized_data\summarized_Achilles tendon.csv
# Summarized CSV saved to: data/summarized_data\summarized_Adductor hiatus.csv
# Summarized CSV saved to: data/summarized_data\summarized_Administrative history.csv
# Summarized CSV saved to: data/summarized_data\summarized_Allergist.csv
# Your max_length is set to 150, but your input_length is only 114. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=57)
# Summarized CSV saved to: data/summarized_data\summarized_Alveolus.csv
# Your max_length is set to 150, but your input_length is only 111. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=55)
# Your max_length is set to 150, but your input_length is only 105. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=52)
# Your max_length is set to 150, but your input_length is only 116. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=58)
# Your max_length is set to 150, but your input_length is only 113. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=56)
# Your max_length is set to 150, but your input_length is only 121. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=60)
# Your max_length is set to 150, but your input_length is only 119. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=59)
# Your max_length is set to 150, but your input_length is only 110. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=55)
# Your max_length is set to 150, but your input_length is only 107. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=53)
# Your max_length is set to 150, but your input_length is only 23. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=11)
# Your max_length is set to 150, but your input_length is only 89. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=44)
# Summarized CSV saved to: data/summarized_data\summarized_Amniotic sac.csv
# Your max_length is set to 150, but your input_length is only 96. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=48)
# Your max_length is set to 150, but your input_length is only 100. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# Your max_length is set to 150, but your input_length is only 110. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=55)
# Your max_length is set to 150, but your input_length is only 97. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=48)
# Your max_length is set to 150, but your input_length is only 91. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=45)
# Your max_length is set to 150, but your input_length is only 84. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=42)
# Your max_length is set to 150, but your input_length is only 83. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=41)
# Your max_length is set to 150, but your input_length is only 93. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=46)
# Your max_length is set to 150, but your input_length is only 104. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=52)
# Your max_length is set to 150, but your input_length is only 87. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=43)
# Your max_length is set to 150, but your input_length is only 91. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=45)
# Your max_length is set to 150, but your input_length is only 92. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=46)
# Your max_length is set to 150, but your input_length is only 120. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=60)
# Your max_length is set to 150, but your input_length is only 134. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=67)
# Your max_length is set to 150, but your input_length is only 126. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=63)
# Your max_length is set to 150, but your input_length is only 117. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=58)
# Your max_length is set to 150, but your input_length is only 105. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=52)
# Your max_length is set to 150, but your input_length is only 98. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=49)
# Your max_length is set to 150, but your input_length is only 108. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=54)
# Your max_length is set to 150, but your input_length is only 105. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=52)
# Your max_length is set to 150, but your input_length is only 104. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=52)
# Your max_length is set to 150, but your input_length is only 95. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=47)
# Your max_length is set to 150, but your input_length is only 107. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=53)
# Your max_length is set to 150, but your input_length is only 102. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=51)
# Your max_length is set to 150, but your input_length is only 111. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=55)
# Your max_length is set to 150, but your input_length is only 107. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=53)
# Your max_length is set to 150, but your input_length is only 100. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# Your max_length is set to 150, but your input_length is only 100. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# Your max_length is set to 150, but your input_length is only 98. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=49)
# Your max_length is set to 150, but your input_length is only 98. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=49)
# Your max_length is set to 150, but your input_length is only 88. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=44)
# Your max_length is set to 150, but your input_length is only 95. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=47)
# Your max_length is set to 150, but your input_length is only 91. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=45)
# Your max_length is set to 150, but your input_length is only 100. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# Your max_length is set to 150, but your input_length is only 112. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=56)
# Your max_length is set to 150, but your input_length is only 107. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=53)
# Your max_length is set to 150, but your input_length is only 96. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=48)
# Your max_length is set to 150, but your input_length is only 105. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=52)

# %%
# Generate Logical Multiple-Choice Questions Using BERT

# %%
# Create MCQs (Multiple-Choice Questions)

# %%
# Save Questions and MCQs to CSV

# %%
 # To compute readability scores (Flesch-Kincaid Grade Level)

def summarize_and_categorize(content):
    """
    Summarize the article content and categorize based on readability.
    """
    # Get the readability score (Flesch-Kincaid Grade Level)
    grade_level = textstat.flesch_kincaid_grade(content)
    # Simplified categorization based on the Flesch-Kincaid Grade Level
    if grade_level <= 6:
        category = 'Easy'
    elif 6 < grade_level <= 12:
        category = 'Medium'
    else:
        category = 'Hard'
    # Simplified summary: just take the first 3 sentences as a basic summary
    sentences = content.split('.')
    summary = '. '.join(sentences[:3]) + '.' if len(sentences) > 3 else content
    return summary, category
# Categories to fetch
categories = ["Medicine", "Medical_specialties", "Health_sciences", "Human_anatomy", "Natural_sciences", "Social_sciences", "Psychology"]
# Loop through each category and fetch article details
for category in categories:
    print(f"\nFetching articles for category: {category}")
    articles = fetch_category_articles(category)
    if articles:  # Only proceed if articles were fetched successfully
        for article in articles:
            title = article['title']
            page_id = article['pageid']
            print(f"\nProcessing article: {title}")
            content = fetch_page_content(page_id)
            summary, difficulty = summarize_and_categorize(content)
            # Output the result
            print(f"Summary: {summary}")
            print(f"Difficulty Level: {difficulty}")
    else:
        print(f"No articles found for category: {category}")
